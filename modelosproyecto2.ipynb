# %% [markdown]
# # Preparación e importación de Datos

# %% [markdown]
# Importación de librerias

# %%
# Importe el conjunto de datos de diabetes y divídalo en entrenamiento y prueba usando scikit-learn
from sklearn.model_selection import train_test_split

import mlflow 
import mlflow.keras
import mlflow.sklearn
from sklearn.metrics import mean_squared_error
import keras
import tensorflow as tf
import tensorflow.keras as tk
from keras import models
from keras import layers

import pandas as pd
import numpy as np

# %% [markdown]
# Lectura De datos

# %%
df = pd.read_csv('DataArbnbBarcelonaLimpio.csv')
df.head()
# Out:
#    host_response_rate  host_acceptance_rate host_is_superhost  \
# 0                0.96                  0.91                 f
# 1                1.00                  0.96                 t
# 2                1.00                  1.00                 f
# 3                1.00                  0.92                 f
# 4                1.00                  0.92                 f
#
#    host_listings_count  host_total_listings_count host_has_profile_pic  \
# 0                   41                         46                    t
# 1                    6                          9                    t
# 2                    3                         15                    t
# 3                    5                          5                    t
# 4                    5                          5                    t
#
#                 neighbourhood_cleansed   latitude  longitude  \
# 0                  la Sagrada FamÃ­lia  41.405560    2.17262
# 1               el BesÃ²s i el Maresme  41.412432    2.21975
# 2  el Camp d'en Grassot i GrÃ cia Nova  41.405660    2.17015
# 3                      el Barri GÃ²tic  41.380620    2.17517
# 4                      el Barri GÃ²tic  41.379780    2.17623
#
#         property_type  ... availability_365  number_of_reviews  \
# 0  Entire rental unit  ...               80                 51
# 1  Entire rental unit  ...              289                 91
# 2  Entire rental unit  ...               64                152
# 3        Entire condo  ...              333                 25
# 4  Entire rental unit  ...              335                271
#
#    availability_eoy  estimated_occupancy_l365d estimated_revenue_l365d  \
# 0                74                         42                    8820
# 1                82                         72                   20520
# 2                64                        138                   23460
# 3               108                        255                   28050
# 4                78                        230                   76590
#
#    review_scores_rating  review_scores_accuracy  instant_bookable  \
# 0                  4.34                    4.40                 t
# 1                  4.82                    4.94                 f
# 2                  4.46                    4.43                 f
# 3                  4.36                    4.45                 f
# 4                  4.57                    4.61                 f
#
#    calculated_host_listings_count  reviews_per_month
# 0                              26               0.34
# 1                               1               0.52
# 2                               2               0.88
# 3                               3               0.14
# 4                               3               1.49
#
# [5 rows x 27 columns]

# %% [markdown]
# Se pasan los datos true false a ceros y unos

# %%
df.replace({"t": 1 ,"f":0},inplace=True)

df.head()
# Out:
# C:\Users\WINDOWS 11\AppData\Local\Temp\ipykernel_9912\3387360302.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({"t": 1 ,"f":0},inplace=True)
#    host_response_rate  host_acceptance_rate  host_is_superhost  \
# 0                0.96                  0.91                  0
# 1                1.00                  0.96                  1
# 2                1.00                  1.00                  0
# 3                1.00                  0.92                  0
# 4                1.00                  0.92                  0
#
#    host_listings_count  host_total_listings_count  host_has_profile_pic  \
# 0                   41                         46                     1
# 1                    6                          9                     1
# 2                    3                         15                     1
# 3                    5                          5                     1
# 4                    5                          5                     1
#
#                 neighbourhood_cleansed   latitude  longitude  \
# 0                  la Sagrada FamÃ­lia  41.405560    2.17262
# 1               el BesÃ²s i el Maresme  41.412432    2.21975
# 2  el Camp d'en Grassot i GrÃ cia Nova  41.405660    2.17015
# 3                      el Barri GÃ²tic  41.380620    2.17517
# 4                      el Barri GÃ²tic  41.379780    2.17623
#
#         property_type  ... availability_365  number_of_reviews  \
# 0  Entire rental unit  ...               80                 51
# 1  Entire rental unit  ...              289                 91
# 2  Entire rental unit  ...               64                152
# 3        Entire condo  ...              333                 25
# 4  Entire rental unit  ...              335                271
#
#    availability_eoy  estimated_occupancy_l365d estimated_revenue_l365d  \
# 0                74                         42                    8820
# 1                82                         72                   20520
# 2                64                        138                   23460
# 3               108                        255                   28050
# 4                78                        230                   76590
#
#    review_scores_rating  review_scores_accuracy  instant_bookable  \
# 0                  4.34                    4.40                 1
# 1                  4.82                    4.94                 0
# 2                  4.46                    4.43                 0
# 3                  4.36                    4.45                 0
# 4                  4.57                    4.61                 0
#
#    calculated_host_listings_count  reviews_per_month
# 0                              26               0.34
# 1                               1               0.52
# 2                               2               0.88
# 3                               3               0.14
# 4                               3               1.49
#
# [5 rows x 27 columns]

# %%
df['price'] = pd.to_numeric(df['price'].str.replace(r'[\$,]', '', regex=True))
df['price'].head()
# Out:
# 0    210.0
# 1    285.0
# 2    170.0
# 3    110.0
# 4    333.0
# Name: price, dtype: float64

# %%
print(df["neighbourhood_cleansed"].unique())
# Out:
# ['la Sagrada FamÃ\xadlia' 'el BesÃ²s i el Maresme'
#  "el Camp d'en Grassot i GrÃ\xa0cia Nova" 'el Barri GÃ²tic'
#  "la Dreta de l'Eixample" 'Vallcarca i els Penitents' 'el Raval'
#  'el Poblenou' 'el Clot' 'el Poble Sec' 'Sant Antoni' 'Sants' 'Pedralbes'
#  'el GuinardÃ³' "l'Antiga Esquerra de l'Eixample" 'la Vila de GrÃ\xa0cia'
#  'Diagonal Mar i el Front MarÃ\xadtim del Poblenou' 'el Fort Pienc'
#  'la Barceloneta' 'Sant MartÃ\xad de ProvenÃ§als'
#  "la Nova Esquerra de l'Eixample" 'SarriÃ\xa0'
#  'el Parc i la Llacuna del Poblenou'
#  'Sant Pere, Santa Caterina i la Ribera'
#  'la Vila OlÃ\xadmpica del Poblenou' 'les Corts' 'el Putxet i el FarrÃ³'
#  'Sant Gervasi - Galvany' 'el CongrÃ©s i els Indians' 'la Bordeta'
#  'la Maternitat i Sant Ramon' 'ProvenÃ§als del Poblenou' 'Sants - Badal'
#  'Navas' 'el Carmel' 'la Salut' 'Hostafrancs' 'la Font de la Guatlla'
#  'Sant Gervasi - la Bonanova' 'les Tres Torres'
#  'Vallvidrera, el Tibidabo i les Planes' 'la Teixonera' 'Can BarÃ³'
#  "el Camp de l'Arpa del Clot" 'la Marina del Prat Vermell'
#  'el Baix GuinardÃ³' 'la Verneda i la Pau' 'Porta'
#  'Vilapicina i la Torre Llobeta' 'el Coll' 'la Sagrera' 'Sant Andreu'
#  "la Font d'en Fargues" 'la Guineueta' 'Horta' "la Vall d'Hebron"
#  'la Prosperitat' 'les Roquetes' 'la Marina de Port'
#  'el TurÃ³ de la Peira' 'Can Peguera' 'Verdun' 'la Trinitat Vella'
#  'la Clota' 'Sant GenÃ\xads dels Agudells' 'Montbau' 'la Trinitat Nova'
#  'el Bon Pastor' 'Canyelles' 'Ciutat Meridiana']

# %% [markdown]
# Se traducen los textos de los barrios aun lenguaje legible

# %%
barrios_corregidos = {
    'la Sagrada FamÃ\xadlia': 'La Sagrada Família',
    'el BesÃ²s i el Maresme': 'El Besòs i el Maresme',
    "el Camp d'en Grassot i GrÃ\xa0cia Nova": "El Camp d'en Grassot i Gràcia Nova",
    'el Barri GÃ²tic': 'El Barri Gòtic',
    "la Dreta de l'Eixample": "La Dreta de l'Eixample",
    'Vallcarca i els Penitents': 'Vallcarca i els Penitents',
    'el Raval': 'El Raval',
    'el Poblenou': 'El Poblenou',
    'el Clot': 'El Clot',
    'el Poble Sec': 'El Poble-sec',
    'Sant Antoni': 'Sant Antoni',
    'Sants': 'Sants',
    'Pedralbes': 'Pedralbes',
    'el GuinardÃ³': 'El Guinardó',
    "l'Antiga Esquerra de l'Eixample": "L'Antiga Esquerra de l'Eixample",
    'la Vila de GrÃ\xa0cia': 'La Vila de Gràcia',
    'Diagonal Mar i el Front MarÃ\xadtim del Poblenou': 'Diagonal Mar i el Front Marítim del Poblenou',
    'el Fort Pienc': 'El Fort Pienc',
    'la Barceloneta': 'La Barceloneta',
    'Sant MartÃ\xad de ProvenÃ§als': 'Sant Martí de Provençals',
    "la Nova Esquerra de l'Eixample": "La Nova Esquerra de l'Eixample",
    'SarriÃ\xa0': 'Sarrià',
    'el Parc i la Llacuna del Poblenou': 'El Parc i la Llacuna del Poblenou',
    'Sant Pere, Santa Caterina i la Ribera': 'Sant Pere, Santa Caterina i la Ribera',
    'la Vila OlÃ\xadmpica del Poblenou': 'La Vila Olímpica del Poblenou',
    'les Corts': 'Les Corts',
    'el Putxet i el FarrÃ³': 'El Putxet i el Farró',
    'Sant Gervasi - Galvany': 'Sant Gervasi - Galvany',
    'el CongrÃ©s i els Indians': 'El Congrés i els Indians',
    'la Bordeta': 'La Bordeta',
    'la Maternitat i Sant Ramon': 'La Maternitat i Sant Ramon',
    'ProvenÃ§als del Poblenou': 'Provençals del Poblenou',
    'Sants - Badal': 'Sants - Badal',
    'Navas': 'Navas',
    'el Carmel': 'El Carmel',
    'la Salut': 'La Salut',
    'Hostafrancs': 'Hostafrancs',
    'la Font de la Guatlla': 'La Font de la Guatlla',
    'Sant Gervasi - la Bonanova': 'Sant Gervasi - la Bonanova',
    'les Tres Torres': 'Les Tres Torres',
    'Vallvidrera, el Tibidabo i les Planes': 'Vallvidrera, el Tibidabo i les Planes',
    'la Teixonera': 'La Teixonera',
    'Can BarÃ³': 'Can Baró',
    "el Camp de l'Arpa del Clot": "El Camp de l'Arpa del Clot",
    'la Marina del Prat Vermell': 'La Marina del Prat Vermell',
    'el Baix GuinardÃ³': 'El Baix Guinardó',
    'la Verneda i la Pau': 'La Verneda i la Pau',
    'Porta': 'Porta',
    'Vilapicina i la Torre Llobeta': 'Vilapicina i la Torre Llobeta',
    'el Coll': 'El Coll',
    'la Sagrera': 'La Sagrera',
    'Sant Andreu': 'Sant Andreu',
    "la Font d'en Fargues": "La Font d'en Fargues",
    'la Guineueta': 'La Guineueta',
    'Horta': 'Horta',
    "la Vall d'Hebron": "La Vall d'Hebron",
    'la Prosperitat': 'La Prosperitat',
    'les Roquetes': 'Les Roquetes',
    'la Marina de Port': 'La Marina de Port',
    'el TurÃ³ de la Peira': 'El Turó de la Peira',
    'Can Peguera': 'Can Peguera',
    'Verdun': 'Verdun',
    'la Trinitat Vella': 'La Trinitat Vella',
    'la Clota': 'La Clota',
    'Sant GenÃ\xads dels Agudells': 'Sant Genís dels Agudells',
    'Montbau': 'Montbau',
    'la Trinitat Nova': 'La Trinitat Nova',
    'el Bon Pastor': 'El Bon Pastor',
    'Canyelles': 'Canyelles',
    'Ciutat Meridiana': 'Ciutat Meridiana'
}

df["neighbourhood_cleansed"].replace( barrios_corregidos, inplace=True)
# Out:
# C:\Users\WINDOWS 11\AppData\Local\Temp\ipykernel_9912\2630809960.py:74: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["neighbourhood_cleansed"].replace( barrios_corregidos, inplace=True)

# %% [markdown]
# # Modelo de Predicción del Precio

# %%
#booleanas y enteros
cat_int_feats = ['host_is_superhost','host_listings_count','host_total_listings_count','host_has_profile_pic','accommodates', 'bedrooms', 'beds', 'minimum_nights', 'maximum_nights', 'availability_365', 'number_of_reviews', 'availability_eoy', 'estimated_occupancy_l365d', 'estimated_revenue_l365d', 'instant_bookable', 'calculated_host_listings_count']
#
cat_str_feats = ['neighbourhood_cleansed', 'property_type', 'room_type']

#variables numericas
num_feats = ['host_response_rate', 'host_acceptance_rate', 'latitude', 'longitude', 'review_scores_rating', 'review_scores_accuracy', 'reviews_per_month']

#se quiere estimar el precio

# %%
feats_ordered = cat_int_feats+cat_str_feats+num_feats
df = df[feats_ordered+['price']]
df.head()
# Out:
#    host_is_superhost  host_listings_count  host_total_listings_count  \
# 0                  0                   41                         46
# 1                  1                    6                          9
# 2                  0                    3                         15
# 3                  0                    5                          5
# 4                  0                    5                          5
#
#    host_has_profile_pic  accommodates  bedrooms  beds  minimum_nights  \
# 0                     1             8       3.0   6.0               1
# 1                     1             5       3.0   4.0               3
# 2                     1             6       2.0   3.0               1
# 3                     1             2       1.0   1.0              31
# 4                     1             9       4.0   6.0               5
#
#    maximum_nights  availability_365  ...       property_type        room_type  \
# 0            1125                80  ...  Entire rental unit  Entire home/apt
# 1              32               289  ...  Entire rental unit  Entire home/apt
# 2              31                64  ...  Entire rental unit  Entire home/apt
# 3             180               333  ...        Entire condo  Entire home/apt
# 4             365               335  ...  Entire rental unit  Entire home/apt
#
#    host_response_rate  host_acceptance_rate   latitude  longitude  \
# 0                0.96                  0.91  41.405560    2.17262
# 1                1.00                  0.96  41.412432    2.21975
# 2                1.00                  1.00  41.405660    2.17015
# 3                1.00                  0.92  41.380620    2.17517
# 4                1.00                  0.92  41.379780    2.17623
#
#   review_scores_rating review_scores_accuracy reviews_per_month  price
# 0                 4.34                   4.40              0.34  210.0
# 1                 4.82                   4.94              0.52  285.0
# 2                 4.46                   4.43              0.88  170.0
# 3                 4.36                   4.45              0.14  110.0
# 4                 4.57                   4.61              1.49  333.0
#
# [5 rows x 27 columns]

# %% [markdown]
# Separación De datos de entrenamiento y validación

# %%
train = df.sample(frac=0.8, random_state=100)
print(train.shape)
# Out:
# (11166, 27)

# %%
test = df.drop(train.index)
test.shape
# Out:
# (2791, 27)

# %%
val = train.sample(frac=0.2, random_state=100)
val.shape
# Out:
# (2233, 27)

# %%
def dataframe_to_dataset(dataframe):
    dataframe = dataframe.copy()
    labels = dataframe.pop("price")
    ds = tf.data.Dataset.from_tensor_slices((dict(dataframe), labels))
    ds = ds.shuffle(buffer_size=len(dataframe))
    return ds

train_ds = dataframe_to_dataset(train)
val_ds = dataframe_to_dataset(val)
test_ds = dataframe_to_dataset(test)

# %%
def encode_numerical_feature(feature, name, dataset):
    # Crea capa de normalización para este feature
    normalizer = keras.layers.Normalization()

    # Prepara el dataset para considerar únicamente la feature de interés (name)
    feature_ds = dataset.map(lambda x, y: x[name]) # selecciona variable
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1)) # deja el tensor de una dimensión

    # Aprende las estadísticas de los datos (media, varianza)
    normalizer.adapt(feature_ds)

    # Aplica la normalización a la variable
    encoded_feature = normalizer(feature)
    return encoded_feature

def encode_categorical_feature(feature, name, dataset, is_string):
    lookup_class = keras.layers.StringLookup if is_string else keras.layers.IntegerLookup
    # Crea una capa Lookup para retornas variables 0/1 (dummies)
    # lookup: busca el valor correspondiente de la variable categórica
    lookup = lookup_class(output_mode="binary")

    # Prepara el dataset para considerar únicamente la feature de interés (name)
    feature_ds = dataset.map(lambda x, y: x[name]) # selecciona variable
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1)) # deja el tensor de una dimensión

    # Aprende el conjunto de posibles valores que toma la variable categórica y asigna enteros
    lookup.adapt(feature_ds)

    # Aplica la conversión de categorías a enteros
    encoded_feature = lookup(feature)
    return encoded_feature

# %% [markdown]
# ## Parámetros Red Neuronal

# %%
mlflow.set_tracking_uri('http://localhost:5000')
# registre el experimento
experiment = mlflow.set_experiment("/proyecto2_Pred_Airbnb")

# %%
inputs = []
for i in cat_int_feats:
    inputs.append(keras.Input(shape=(1,), name=i, dtype="int64"))
for i in cat_str_feats:
    inputs.append(keras.Input(shape=(1,), name=i, dtype="string"))
for i in num_feats:
    inputs.append(keras.Input(shape=(1,), name=i))

# Codificación/normalización de features (usa las funciones definidas en el notebook)
feats_encoded = []
for i, feat in enumerate(cat_int_feats):
    feats_encoded.append(encode_categorical_feature(inputs[i], feat, train_ds, False))

len_feats = len(feats_encoded)
for i, feat in enumerate(cat_str_feats):
    feats_encoded.append(encode_categorical_feature(inputs[len_feats + i], feat, train_ds, True))

len_feats = len(feats_encoded)
for i, feat in enumerate(num_feats):
    feats_encoded.append(encode_numerical_feature(inputs[len_feats + i], feat, train_ds))

# Concatenar todas las features codificadas
all_feats = keras.layers.concatenate(feats_encoded)

# %%
#mlflow.end_run()
n_epochs = 10
learning_rate = 0.05
num_hidden_units = 64
num_hidden_layers = 5
batch_size = 32

def run_mlflow_model(run_name="Mlflow_modelo_Airbnb_pred",
                     n_epochs=n_epochs,
                     learning_rate=learning_rate,
                     num_hidden_units=num_hidden_units,
                     num_hidden_layers=num_hidden_layers,
                     batch_size=batch_size):
    """
    Construye y entrena un modelo usando la estructura de 'actd_redes' y registra parámetros/ejecución en MLflow.
    Requiere que existan en el scope: cat_int_feats, cat_str_feats, num_feats, train_ds, val_ds, encode_* funciones.
    """
    mlflow.start_run(run_name=run_name)
    mlflow.log_param("epocas", n_epochs)
    mlflow.log_param("learning_rate", learning_rate)
    mlflow.log_param("num_hidden_units", num_hidden_units)
    mlflow.log_param("num_hidden_layers", num_hidden_layers)
    mlflow.log_param("batch_size", batch_size)
    mlflow.keras.autolog()

    # Capas ocultas según parámetros
    x = all_feats
    for _ in range(int(num_hidden_layers)):
        x = keras.layers.Dense(int(num_hidden_units), activation='relu')(x)

    # Neurona de salida con relu
    outputs = keras.layers.Dense(1, activation='relu')(x)

    model = keras.Model(inputs=inputs, outputs=outputs)

    # Optimizador con learning_rate pasado
    optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='mean_absolute_error', metrics= ['mse'])

    # Ajustar batch size en los tf.data.Dataset antes del entrenamiento
    train_ds_batched = train_ds.batch(batch_size)
    val_ds_batched = val_ds.batch(batch_size)

    # Entrenamiento (usa los tf.data.Dataset existentes: train_ds_batched y val_ds_batched)
    history = model.fit(train_ds_batched, validation_data=val_ds_batched, epochs=int(n_epochs))

    mlflow.log_metric("mse", history.history['val_mse'][-1])  

    mlflow.end_run(status='FINISHED')
    return model, history

# %%
#mlflow.end_run()

#MEJOR 

"""
n_epochs = 50
learning_rate = 0.001
num_hidden_units = 64
num_hidden_layers = 5
batch_size = 32

"""
n_epochs = 200
learning_rate = 0.001
num_hidden_units = 64
num_hidden_layers = 5
batch_size = 32

# %%
(experimentID, runID) = run_mlflow_model("Mlflow_modelo_Airbnb_pred", n_epochs,  learning_rate, num_hidden_units, num_hidden_layers, batch_size)
print("MLflow Run completed with run_id {} and experiment_id {}".format(runID, experimentID))
# Out:
# 2025/11/18 20:33:05 WARNING mlflow.keras.autologging: Failed to log dataset information to MLflow. Reason: 'ascii' codec can't decode byte 0xc3 in position 6: ordinal not in range(128)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Epoch 1/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 91.2313 - mse: 111954.1719 - val_loss: 59.1326 - val_mse: 72717.5703
# Epoch 2/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 62.2876 - mse: 96695.5312 - val_loss: 49.2979 - val_mse: 66594.6406
# Epoch 3/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 54.6305 - mse: 90942.6328 - val_loss: 43.8952 - val_mse: 63397.1094
# Epoch 4/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 49.4383 - mse: 86808.3672 - val_loss: 42.8884 - val_mse: 59101.3828
# Epoch 5/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 45.4353 - mse: 83071.5000 - val_loss: 38.6567 - val_mse: 58415.7773
# Epoch 6/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 42.8323 - mse: 80493.7188 - val_loss: 36.4957 - val_mse: 54740.7852
# Epoch 7/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 40.0201 - mse: 76920.1953 - val_loss: 36.9825 - val_mse: 51738.1680
# Epoch 8/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 37.8434 - mse: 73995.9297 - val_loss: 31.4346 - val_mse: 51462.8008
# Epoch 9/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 35.8791 - mse: 71516.9609 - val_loss: 29.6523 - val_mse: 48635.1367
# Epoch 10/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 34.4911 - mse: 68225.3984 - val_loss: 28.9604 - val_mse: 45965.2734
# Epoch 11/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 32.6166 - mse: 64590.9258 - val_loss: 28.5366 - val_mse: 43175.5039
# Epoch 12/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 31.0557 - mse: 60630.4922 - val_loss: 26.6856 - val_mse: 39961.8750
# Epoch 13/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 29.9224 - mse: 55580.8125 - val_loss: 25.1540 - val_mse: 33795.0234
# Epoch 14/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 28.4801 - mse: 49834.7695 - val_loss: 23.0372 - val_mse: 29040.2402
# Epoch 15/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 26.5621 - mse: 43795.8672 - val_loss: 21.4723 - val_mse: 24302.4766
# Epoch 16/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 24.8189 - mse: 35840.3906 - val_loss: 23.8712 - val_mse: 18940.8535
# Epoch 17/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 23.3831 - mse: 28735.0566 - val_loss: 23.2081 - val_mse: 15405.1943
# Epoch 18/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 22.1585 - mse: 24899.3008 - val_loss: 17.4442 - val_mse: 13338.4365
# Epoch 19/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 21.2030 - mse: 22634.5430 - val_loss: 16.9918 - val_mse: 13318.1133
# Epoch 20/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 19.2075 - mse: 20005.2812 - val_loss: 16.6207 - val_mse: 13261.6270
# Epoch 21/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 18.5542 - mse: 19065.5469 - val_loss: 16.6971 - val_mse: 13032.7754
# Epoch 22/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 18.8160 - mse: 18902.2109 - val_loss: 16.1216 - val_mse: 13008.2686
# Epoch 23/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 17.2766 - mse: 16885.1934 - val_loss: 15.8598 - val_mse: 13173.4990
# Epoch 24/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 16.8332 - mse: 16671.2500 - val_loss: 14.9620 - val_mse: 12621.8682
# Epoch 25/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 16.4713 - mse: 15799.0215 - val_loss: 14.8673 - val_mse: 12627.7900
# Epoch 26/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 16.2678 - mse: 14928.8311 - val_loss: 15.6013 - val_mse: 13043.8545
# Epoch 27/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 15.9881 - mse: 15429.3037 - val_loss: 15.9617 - val_mse: 13895.9824
# Epoch 28/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 15.8633 - mse: 14408.3770 - val_loss: 13.7557 - val_mse: 12365.7266
# Epoch 29/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 15.1179 - mse: 13842.9648 - val_loss: 13.9463 - val_mse: 12563.0879
# Epoch 30/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 14.5407 - mse: 13205.5566 - val_loss: 14.5456 - val_mse: 13038.9131
# Epoch 31/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 14.3196 - mse: 12856.8027 - val_loss: 13.6899 - val_mse: 12762.5283
# Epoch 32/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 14.4573 - mse: 12902.3076 - val_loss: 13.7395 - val_mse: 12672.0693
# Epoch 33/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 13.8381 - mse: 12675.5205 - val_loss: 14.9328 - val_mse: 13691.9990
# Epoch 34/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 14.0549 - mse: 12108.3643 - val_loss: 13.4649 - val_mse: 12480.6504
# Epoch 35/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 13.4944 - mse: 11518.7051 - val_loss: 12.5806 - val_mse: 12604.1572
# Epoch 36/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 13.4775 - mse: 11459.7676 - val_loss: 13.4161 - val_mse: 12885.5605
# Epoch 37/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 13.1927 - mse: 11461.8867 - val_loss: 13.3381 - val_mse: 12930.7510
# Epoch 38/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 13.0773 - mse: 11486.0908 - val_loss: 14.4172 - val_mse: 12710.0186
# Epoch 39/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 12.9072 - mse: 11436.5264 - val_loss: 13.3586 - val_mse: 12186.8379
# Epoch 40/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 12.8895 - mse: 11408.7783 - val_loss: 15.3849 - val_mse: 13687.4648
# Epoch 41/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 12.7454 - mse: 11289.8330 - val_loss: 14.4221 - val_mse: 12067.5381
# Epoch 42/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 12.3708 - mse: 11090.4736 - val_loss: 12.0984 - val_mse: 11951.8057
# Epoch 43/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 12.3778 - mse: 10974.9795 - val_loss: 13.6652 - val_mse: 11851.2051
# Epoch 44/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 12.5260 - mse: 11024.8076 - val_loss: 14.7517 - val_mse: 11824.1084
# Epoch 45/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 12.3080 - mse: 10772.8867 - val_loss: 12.3903 - val_mse: 11894.5137
# Epoch 46/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 12.1437 - mse: 10787.7588 - val_loss: 12.7028 - val_mse: 11569.3965
# Epoch 47/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 11.7918 - mse: 10659.0303 - val_loss: 11.9853 - val_mse: 11178.1504
# Epoch 48/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 11.6543 - mse: 10706.6279 - val_loss: 13.3794 - val_mse: 11029.5889
# Epoch 49/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 11.6056 - mse: 10557.6348 - val_loss: 10.9494 - val_mse: 10500.0088
# Epoch 50/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 11.6890 - mse: 10655.2803 - val_loss: 10.8703 - val_mse: 10386.8633
# Epoch 51/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 11.1767 - mse: 10279.0332 - val_loss: 10.8708 - val_mse: 10491.2041
# Epoch 52/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 11.4695 - mse: 10356.5713 - val_loss: 11.1402 - val_mse: 10603.5176
# Epoch 53/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 11.2599 - mse: 10132.1436 - val_loss: 10.8196 - val_mse: 9427.8311
# Epoch 54/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 10.7919 - mse: 9983.5254 - val_loss: 12.2400 - val_mse: 9749.0928
# Epoch 55/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 11.0636 - mse: 9838.5947 - val_loss: 11.2550 - val_mse: 8778.2236
# Epoch 56/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 10.7565 - mse: 10019.4092 - val_loss: 10.1126 - val_mse: 8750.2051
# Epoch 57/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 10.7785 - mse: 9842.8750 - val_loss: 10.4637 - val_mse: 7940.7334
# Epoch 58/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 10.6791 - mse: 9726.1104 - val_loss: 9.8080 - val_mse: 8503.8428
# Epoch 59/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 10.2056 - mse: 9648.9590 - val_loss: 10.4776 - val_mse: 8392.3682
# Epoch 60/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 10.5184 - mse: 9633.6816 - val_loss: 10.3405 - val_mse: 8122.2515
# Epoch 61/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 10.5318 - mse: 9478.3213 - val_loss: 9.5819 - val_mse: 7899.2646
# Epoch 62/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 10.4975 - mse: 9328.4912 - val_loss: 10.5716 - val_mse: 7717.6660
# Epoch 63/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 10.2182 - mse: 9297.4619 - val_loss: 9.4124 - val_mse: 7760.8403
# Epoch 64/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.8293 - mse: 9247.9883 - val_loss: 10.2911 - val_mse: 7776.0679
# Epoch 65/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 10.0888 - mse: 9195.1123 - val_loss: 9.5426 - val_mse: 7155.6978
# Epoch 66/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.9196 - mse: 8950.5459 - val_loss: 9.3414 - val_mse: 7145.4697
# Epoch 67/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 10.2984 - mse: 9283.4375 - val_loss: 9.4063 - val_mse: 6723.1816
# Epoch 68/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 10.0031 - mse: 8822.7178 - val_loss: 9.9793 - val_mse: 7046.3921
# Epoch 69/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 10.2202 - mse: 9018.0400 - val_loss: 10.1071 - val_mse: 6393.7759
# Epoch 70/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.7026 - mse: 8998.8594 - val_loss: 10.1101 - val_mse: 7571.0137
# Epoch 71/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.5592 - mse: 8767.9121 - val_loss: 8.8915 - val_mse: 6292.1118
# Epoch 72/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.4654 - mse: 8565.3730 - val_loss: 9.4037 - val_mse: 6002.6782
# Epoch 73/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.4677 - mse: 8303.2539 - val_loss: 9.3161 - val_mse: 6102.6230
# Epoch 74/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.6157 - mse: 8484.1426 - val_loss: 10.4358 - val_mse: 5804.1108
# Epoch 75/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.6009 - mse: 8472.1328 - val_loss: 8.5818 - val_mse: 6171.3838
# Epoch 76/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.8324 - mse: 8711.3340 - val_loss: 8.5801 - val_mse: 5601.8218
# Epoch 77/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.4879 - mse: 8031.2764 - val_loss: 9.4422 - val_mse: 5591.1841
# Epoch 78/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.4946 - mse: 7980.3584 - val_loss: 9.5663 - val_mse: 5427.6348
# Epoch 79/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.6345 - mse: 8136.9873 - val_loss: 9.1919 - val_mse: 5080.6035
# Epoch 80/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.4597 - mse: 7731.3896 - val_loss: 8.5601 - val_mse: 5170.2881
# Epoch 81/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 9.0012 - mse: 7724.5366 - val_loss: 9.7409 - val_mse: 5143.2124
# Epoch 82/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 9.0245 - mse: 7621.4814 - val_loss: 8.8043 - val_mse: 4844.8291
# Epoch 83/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 8.9854 - mse: 7540.4736 - val_loss: 10.6641 - val_mse: 5100.8584
# Epoch 84/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.1705 - mse: 7445.5366 - val_loss: 9.2095 - val_mse: 5223.5039
# Epoch 85/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 8.6834 - mse: 6924.7056 - val_loss: 8.4864 - val_mse: 4535.2319
# Epoch 86/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 8.7234 - mse: 6911.4219 - val_loss: 8.6357 - val_mse: 5051.5586
# Epoch 87/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 8.7344 - mse: 6537.9028 - val_loss: 8.5872 - val_mse: 4510.5000
# Epoch 88/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 9.2420 - mse: 6542.3975 - val_loss: 7.8563 - val_mse: 4330.0562
# Epoch 89/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 8.7035 - mse: 6148.7124 - val_loss: 7.8211 - val_mse: 4208.8867
# Epoch 90/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 8.7372 - mse: 6265.5957 - val_loss: 8.2819 - val_mse: 3948.7112
# Epoch 91/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 8.8708 - mse: 5974.8003 - val_loss: 7.8648 - val_mse: 3605.0569
# Epoch 92/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 8.9007 - mse: 5687.4165 - val_loss: 7.3958 - val_mse: 3721.2786
# Epoch 93/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 8.5909 - mse: 5472.4873 - val_loss: 8.9152 - val_mse: 4339.3921
# Epoch 94/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 8.4979 - mse: 5223.1123 - val_loss: 7.7541 - val_mse: 4116.6001
# Epoch 95/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 8.2727 - mse: 5017.5723 - val_loss: 7.5991 - val_mse: 3075.1987
# Epoch 96/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 8.2273 - mse: 4889.1816 - val_loss: 8.3158 - val_mse: 3868.2769
# Epoch 97/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 8.1348 - mse: 4778.2764 - val_loss: 8.0627 - val_mse: 3635.8145
# Epoch 98/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 8.3894 - mse: 4466.0034 - val_loss: 8.5922 - val_mse: 3613.3333
# Epoch 99/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 8.4194 - mse: 4389.7964 - val_loss: 8.3710 - val_mse: 3067.1821
# Epoch 100/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 8.1039 - mse: 4187.5791 - val_loss: 7.3399 - val_mse: 2922.9714
# Epoch 101/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 8.3885 - mse: 4040.4314 - val_loss: 9.9291 - val_mse: 2830.5356
# Epoch 102/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.9874 - mse: 3718.0293 - val_loss: 7.3595 - val_mse: 2670.9917
# Epoch 103/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 8.0497 - mse: 3588.9146 - val_loss: 7.8836 - val_mse: 2614.4265
# Epoch 104/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.8083 - mse: 3399.8782 - val_loss: 8.4085 - val_mse: 2653.8735
# Epoch 105/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 7.8001 - mse: 2930.1033 - val_loss: 7.7208 - val_mse: 2342.7346
# Epoch 106/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 7.8499 - mse: 2957.1604 - val_loss: 7.3734 - val_mse: 2583.5425
# Epoch 107/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.7750 - mse: 3150.2405 - val_loss: 7.2394 - val_mse: 2249.8057
# Epoch 108/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.7249 - mse: 2769.8577 - val_loss: 6.9976 - val_mse: 1675.1659
# Epoch 109/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.5401 - mse: 2375.0303 - val_loss: 6.9443 - val_mse: 2042.2933
# Epoch 110/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5879 - mse: 2427.1558 - val_loss: 6.9203 - val_mse: 1676.8273
# Epoch 111/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.9365 - mse: 2168.0774 - val_loss: 8.5934 - val_mse: 2127.8120
# Epoch 112/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.6320 - mse: 2065.2139 - val_loss: 8.0120 - val_mse: 1869.6836
# Epoch 113/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.6764 - mse: 2015.8636 - val_loss: 6.6186 - val_mse: 1456.5664
# Epoch 114/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.5819 - mse: 1833.0273 - val_loss: 7.8426 - val_mse: 1550.8669
# Epoch 115/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.8591 - mse: 2102.6628 - val_loss: 6.8556 - val_mse: 1268.6755
# Epoch 116/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.6873 - mse: 1635.8267 - val_loss: 6.4155 - val_mse: 903.7939
# Epoch 117/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.3165 - mse: 1647.5135 - val_loss: 6.5673 - val_mse: 1204.5680
# Epoch 118/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.2058 - mse: 1714.5273 - val_loss: 6.7847 - val_mse: 1095.9009
# Epoch 119/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.9932 - mse: 1428.9603 - val_loss: 6.1250 - val_mse: 816.6912
# Epoch 120/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.0680 - mse: 1328.9664 - val_loss: 8.1819 - val_mse: 1015.4280
# Epoch 121/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.5585 - mse: 1231.6044 - val_loss: 6.3854 - val_mse: 754.1526
# Epoch 122/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.1405 - mse: 1229.0106 - val_loss: 8.0064 - val_mse: 1065.2871
# Epoch 123/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.9767 - mse: 1008.8942 - val_loss: 7.6631 - val_mse: 947.5078
# Epoch 124/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.3094 - mse: 1188.1808 - val_loss: 7.9406 - val_mse: 697.9680
# Epoch 125/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.0777 - mse: 982.9758 - val_loss: 7.4013 - val_mse: 1216.1533
# Epoch 126/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.1609 - mse: 1164.5269 - val_loss: 6.3904 - val_mse: 561.9305
# Epoch 127/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.9023 - mse: 941.8996 - val_loss: 5.7288 - val_mse: 525.6549
# Epoch 128/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.8259 - mse: 1006.4225 - val_loss: 6.5023 - val_mse: 713.2096
# Epoch 129/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.9058 - mse: 1080.6389 - val_loss: 5.6860 - val_mse: 434.5125
# Epoch 130/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.7230 - mse: 996.7682 - val_loss: 5.3421 - val_mse: 376.5126
# Epoch 131/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.5710 - mse: 850.3276 - val_loss: 6.0319 - val_mse: 471.2977
# Epoch 132/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 6.6596 - mse: 979.0981 - val_loss: 6.8263 - val_mse: 463.6399
# Epoch 133/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 6.6052 - mse: 973.4963 - val_loss: 6.0469 - val_mse: 802.0336
# Epoch 134/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.7285 - mse: 1115.9836 - val_loss: 7.1433 - val_mse: 799.6906
# Epoch 135/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 6.4833 - mse: 850.3463 - val_loss: 6.1195 - val_mse: 394.9035
# Epoch 136/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.5444 - mse: 927.0241 - val_loss: 5.3169 - val_mse: 473.4678
# Epoch 137/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.8885 - mse: 994.5032 - val_loss: 8.6344 - val_mse: 1419.3230
# Epoch 138/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.7715 - mse: 961.5786 - val_loss: 5.8425 - val_mse: 614.4776
# Epoch 139/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.5305 - mse: 950.6117 - val_loss: 5.9290 - val_mse: 451.8934
# Epoch 140/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.4275 - mse: 711.6772 - val_loss: 6.3751 - val_mse: 684.1780
# Epoch 141/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.4798 - mse: 897.8323 - val_loss: 5.9159 - val_mse: 594.5844
# Epoch 142/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.3186 - mse: 828.3705 - val_loss: 5.0960 - val_mse: 319.3093
# Epoch 143/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.6570 - mse: 1020.2720 - val_loss: 5.4856 - val_mse: 452.2235
# Epoch 144/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.4168 - mse: 892.4360 - val_loss: 5.2235 - val_mse: 417.1985
# Epoch 145/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.2880 - mse: 855.5862 - val_loss: 5.2467 - val_mse: 342.7924
# Epoch 146/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.2877 - mse: 792.1027 - val_loss: 6.2736 - val_mse: 420.1271
# Epoch 147/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.3657 - mse: 899.6796 - val_loss: 5.9458 - val_mse: 477.2815
# Epoch 148/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.3609 - mse: 888.5893 - val_loss: 6.3281 - val_mse: 421.3967
# Epoch 149/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.3632 - mse: 867.1311 - val_loss: 5.3237 - val_mse: 319.0375
# Epoch 150/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.2258 - mse: 897.4634 - val_loss: 5.9832 - val_mse: 602.9279
# Epoch 151/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.0678 - mse: 768.9036 - val_loss: 5.3252 - val_mse: 366.0002
# Epoch 152/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.3263 - mse: 802.7648 - val_loss: 5.3674 - val_mse: 342.0861
# Epoch 153/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.3553 - mse: 896.6604 - val_loss: 5.9778 - val_mse: 570.8804
# Epoch 154/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.2440 - mse: 826.7616 - val_loss: 5.4076 - val_mse: 343.9914
# Epoch 155/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.1037 - mse: 723.0082 - val_loss: 5.3524 - val_mse: 392.0035
# Epoch 156/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.4599 - mse: 975.5174 - val_loss: 5.2042 - val_mse: 274.4873
# Epoch 157/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.0167 - mse: 739.9213 - val_loss: 5.8477 - val_mse: 346.1654
# Epoch 158/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.0787 - mse: 741.9358 - val_loss: 6.0284 - val_mse: 631.8425
# Epoch 159/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.1663 - mse: 760.7097 - val_loss: 6.3347 - val_mse: 257.3330
# Epoch 160/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 6.0839 - mse: 709.3473 - val_loss: 5.8773 - val_mse: 498.9478
# Epoch 161/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.0317 - mse: 732.2994 - val_loss: 5.3400 - val_mse: 739.6454
# Epoch 162/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 6.1214 - mse: 844.5892 - val_loss: 5.4701 - val_mse: 458.6371
# Epoch 163/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 5.7440 - mse: 717.8645 - val_loss: 4.9904 - val_mse: 361.5655
# Epoch 164/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.9262 - mse: 703.2318 - val_loss: 6.5366 - val_mse: 974.0447
# Epoch 165/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.1241 - mse: 743.8731 - val_loss: 5.6053 - val_mse: 544.0138
# Epoch 166/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.0735 - mse: 802.3507 - val_loss: 5.1393 - val_mse: 666.7830
# Epoch 167/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.0409 - mse: 740.7651 - val_loss: 5.2330 - val_mse: 358.7516
# Epoch 168/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 5.7847 - mse: 706.0978 - val_loss: 6.0874 - val_mse: 851.0174
# Epoch 169/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.0441 - mse: 848.8630 - val_loss: 5.4044 - val_mse: 299.7397
# Epoch 170/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 5.8083 - mse: 665.9890 - val_loss: 5.5317 - val_mse: 570.4857
# Epoch 171/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.7502 - mse: 641.3316 - val_loss: 5.5327 - val_mse: 827.6925
# Epoch 172/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.7281 - mse: 612.1537 - val_loss: 5.1375 - val_mse: 313.4037
# Epoch 173/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 5.7877 - mse: 752.6359 - val_loss: 5.2071 - val_mse: 403.9784
# Epoch 174/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.7773 - mse: 650.2309 - val_loss: 5.2429 - val_mse: 240.6896
# Epoch 175/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.0346 - mse: 683.2697 - val_loss: 6.0157 - val_mse: 656.8262
# Epoch 176/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.8404 - mse: 676.0976 - val_loss: 5.2530 - val_mse: 436.9537
# Epoch 177/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.8242 - mse: 777.9769 - val_loss: 5.6446 - val_mse: 611.1801
# Epoch 178/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 5.7235 - mse: 679.6439 - val_loss: 6.5620 - val_mse: 389.3505
# Epoch 179/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.8213 - mse: 651.8883 - val_loss: 5.0055 - val_mse: 356.5589
# Epoch 180/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.5700 - mse: 649.8703 - val_loss: 4.5897 - val_mse: 284.7047
# Epoch 181/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.6218 - mse: 691.4697 - val_loss: 5.3814 - val_mse: 448.2157
# Epoch 182/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.6326 - mse: 676.1236 - val_loss: 4.4478 - val_mse: 220.1904
# Epoch 183/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.7039 - mse: 707.2305 - val_loss: 4.9221 - val_mse: 407.7939
# Epoch 184/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 5.6296 - mse: 630.5213 - val_loss: 5.3801 - val_mse: 412.5027
# Epoch 185/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.7686 - mse: 625.6869 - val_loss: 4.9737 - val_mse: 574.4976
# Epoch 186/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 5.7793 - mse: 697.1913 - val_loss: 5.5415 - val_mse: 226.6504
# Epoch 187/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.4899 - mse: 581.3548 - val_loss: 5.2698 - val_mse: 485.6308
# Epoch 188/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.5050 - mse: 663.8260 - val_loss: 6.3054 - val_mse: 414.7775
# Epoch 189/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 5.7322 - mse: 738.3321 - val_loss: 4.9271 - val_mse: 329.9696
# Epoch 190/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 5.4973 - mse: 642.1061 - val_loss: 4.5999 - val_mse: 208.6509
# Epoch 191/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.2299 - mse: 550.0303 - val_loss: 4.6043 - val_mse: 322.3595
# Epoch 192/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.5501 - mse: 710.2228 - val_loss: 5.4647 - val_mse: 326.2722
# Epoch 193/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 5.2801 - mse: 557.4308 - val_loss: 4.9738 - val_mse: 279.5130
# Epoch 194/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 5.5100 - mse: 702.4277 - val_loss: 5.1650 - val_mse: 479.3159
# Epoch 195/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 5.4430 - mse: 615.4652 - val_loss: 4.8877 - val_mse: 279.2703
# Epoch 196/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 5.5877 - mse: 659.0118 - val_loss: 6.3657 - val_mse: 412.1553
# Epoch 197/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 5.4391 - mse: 599.0258 - val_loss: 5.1267 - val_mse: 338.2022
# Epoch 198/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 5.6244 - mse: 718.5795 - val_loss: 5.0419 - val_mse: 353.2464
# Epoch 199/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 5.3199 - mse: 510.1718 - val_loss: 4.7842 - val_mse: 225.7390
# Epoch 200/200
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 5.3209 - mse: 635.2486 - val_loss: 4.2721 - val_mse: 147.8551
# 2025/11/18 20:38:07 WARNING mlflow.keras.autologging: Failed to get model signature, reason: Creating Schema with multiple unnamed TensorSpecs is not supported. Please provide names for each TensorSpec.
# 2025/11/18 20:38:07 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/11/18 20:38:08 WARNING mlflow.keras.save: You are saving a Keras model without specifying model signature.
# 2025/11/18 20:38:15 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run Mlflow_modelo_Airbnb_pred at: http://localhost:5000/#/experiments/255457792531442980/runs/8bf77dc9119f4417b2eddd37bf056bfb
# 🧪 View experiment at: http://localhost:5000/#/experiments/255457792531442980
# MLflow Run completed with run_id <keras.src.callbacks.history.History object at 0x000002870CFFBD10> and experiment_id <Functional name=functional_2, built=True>
