# %% [markdown]
# # Preparación e importación de Datos

# %% [markdown]
# Importación de librerias

# %%
# Importe el conjunto de datos de diabetes y divídalo en entrenamiento y prueba usando scikit-learn
from sklearn.model_selection import train_test_split

import mlflow 
import mlflow.keras
import mlflow.sklearn
from sklearn.metrics import mean_squared_error
import keras
import tensorflow as tf
import tensorflow.keras as tk
from keras import models
from keras import layers

import pandas as pd
import numpy as np

# %% [markdown]
# Lectura De datos

# %%
df = pd.read_csv('DataArbnbBarcelonaLimpio.csv')
df.head()
# Out:
#    host_response_rate  host_acceptance_rate host_is_superhost  \
# 0                0.96                  0.91                 f
# 1                1.00                  0.96                 t
# 2                1.00                  1.00                 f
# 3                1.00                  0.92                 f
# 4                1.00                  0.92                 f
#
#    host_listings_count  host_total_listings_count host_has_profile_pic  \
# 0                   41                         46                    t
# 1                    6                          9                    t
# 2                    3                         15                    t
# 3                    5                          5                    t
# 4                    5                          5                    t
#
#                 neighbourhood_cleansed   latitude  longitude  \
# 0                  la Sagrada FamÃ­lia  41.405560    2.17262
# 1               el BesÃ²s i el Maresme  41.412432    2.21975
# 2  el Camp d'en Grassot i GrÃ cia Nova  41.405660    2.17015
# 3                      el Barri GÃ²tic  41.380620    2.17517
# 4                      el Barri GÃ²tic  41.379780    2.17623
#
#         property_type  ... availability_365  number_of_reviews  \
# 0  Entire rental unit  ...               80                 51
# 1  Entire rental unit  ...              289                 91
# 2  Entire rental unit  ...               64                152
# 3        Entire condo  ...              333                 25
# 4  Entire rental unit  ...              335                271
#
#    availability_eoy  estimated_occupancy_l365d estimated_revenue_l365d  \
# 0                74                         42                    8820
# 1                82                         72                   20520
# 2                64                        138                   23460
# 3               108                        255                   28050
# 4                78                        230                   76590
#
#    review_scores_rating  review_scores_accuracy  instant_bookable  \
# 0                  4.34                    4.40                 t
# 1                  4.82                    4.94                 f
# 2                  4.46                    4.43                 f
# 3                  4.36                    4.45                 f
# 4                  4.57                    4.61                 f
#
#    calculated_host_listings_count  reviews_per_month
# 0                              26               0.34
# 1                               1               0.52
# 2                               2               0.88
# 3                               3               0.14
# 4                               3               1.49
#
# [5 rows x 27 columns]

# %% [markdown]
# Se pasan los datos true false a ceros y unos

# %%
df.replace({"t": 1 ,"f":0},inplace=True)

df.head()
# Out:
# C:\Users\Tomás Otálora\AppData\Local\Temp\ipykernel_16884\3387360302.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({"t": 1 ,"f":0},inplace=True)
#    host_response_rate  host_acceptance_rate  host_is_superhost  \
# 0                0.96                  0.91                  0
# 1                1.00                  0.96                  1
# 2                1.00                  1.00                  0
# 3                1.00                  0.92                  0
# 4                1.00                  0.92                  0
#
#    host_listings_count  host_total_listings_count  host_has_profile_pic  \
# 0                   41                         46                     1
# 1                    6                          9                     1
# 2                    3                         15                     1
# 3                    5                          5                     1
# 4                    5                          5                     1
#
#                 neighbourhood_cleansed   latitude  longitude  \
# 0                  la Sagrada FamÃ­lia  41.405560    2.17262
# 1               el BesÃ²s i el Maresme  41.412432    2.21975
# 2  el Camp d'en Grassot i GrÃ cia Nova  41.405660    2.17015
# 3                      el Barri GÃ²tic  41.380620    2.17517
# 4                      el Barri GÃ²tic  41.379780    2.17623
#
#         property_type  ... availability_365  number_of_reviews  \
# 0  Entire rental unit  ...               80                 51
# 1  Entire rental unit  ...              289                 91
# 2  Entire rental unit  ...               64                152
# 3        Entire condo  ...              333                 25
# 4  Entire rental unit  ...              335                271
#
#    availability_eoy  estimated_occupancy_l365d estimated_revenue_l365d  \
# 0                74                         42                    8820
# 1                82                         72                   20520
# 2                64                        138                   23460
# 3               108                        255                   28050
# 4                78                        230                   76590
#
#    review_scores_rating  review_scores_accuracy  instant_bookable  \
# 0                  4.34                    4.40                 1
# 1                  4.82                    4.94                 0
# 2                  4.46                    4.43                 0
# 3                  4.36                    4.45                 0
# 4                  4.57                    4.61                 0
#
#    calculated_host_listings_count  reviews_per_month
# 0                              26               0.34
# 1                               1               0.52
# 2                               2               0.88
# 3                               3               0.14
# 4                               3               1.49
#
# [5 rows x 27 columns]

# %%
df['price'] = pd.to_numeric(df['price'].str.replace(r'[\$,]', '', regex=True))
df['price'].head()
# Out:
# 0    210.0
# 1    285.0
# 2    170.0
# 3    110.0
# 4    333.0
# Name: price, dtype: float64

# %%
print(df["neighbourhood_cleansed"].unique())
# Out:
# ['la Sagrada FamÃ\xadlia' 'el BesÃ²s i el Maresme'
#  "el Camp d'en Grassot i GrÃ\xa0cia Nova" 'el Barri GÃ²tic'
#  "la Dreta de l'Eixample" 'Vallcarca i els Penitents' 'el Raval'
#  'el Poblenou' 'el Clot' 'el Poble Sec' 'Sant Antoni' 'Sants' 'Pedralbes'
#  'el GuinardÃ³' "l'Antiga Esquerra de l'Eixample" 'la Vila de GrÃ\xa0cia'
#  'Diagonal Mar i el Front MarÃ\xadtim del Poblenou' 'el Fort Pienc'
#  'la Barceloneta' 'Sant MartÃ\xad de ProvenÃ§als'
#  "la Nova Esquerra de l'Eixample" 'SarriÃ\xa0'
#  'el Parc i la Llacuna del Poblenou'
#  'Sant Pere, Santa Caterina i la Ribera'
#  'la Vila OlÃ\xadmpica del Poblenou' 'les Corts' 'el Putxet i el FarrÃ³'
#  'Sant Gervasi - Galvany' 'el CongrÃ©s i els Indians' 'la Bordeta'
#  'la Maternitat i Sant Ramon' 'ProvenÃ§als del Poblenou' 'Sants - Badal'
#  'Navas' 'el Carmel' 'la Salut' 'Hostafrancs' 'la Font de la Guatlla'
#  'Sant Gervasi - la Bonanova' 'les Tres Torres'
#  'Vallvidrera, el Tibidabo i les Planes' 'la Teixonera' 'Can BarÃ³'
#  "el Camp de l'Arpa del Clot" 'la Marina del Prat Vermell'
#  'el Baix GuinardÃ³' 'la Verneda i la Pau' 'Porta'
#  'Vilapicina i la Torre Llobeta' 'el Coll' 'la Sagrera' 'Sant Andreu'
#  "la Font d'en Fargues" 'la Guineueta' 'Horta' "la Vall d'Hebron"
#  'la Prosperitat' 'les Roquetes' 'la Marina de Port'
#  'el TurÃ³ de la Peira' 'Can Peguera' 'Verdun' 'la Trinitat Vella'
#  'la Clota' 'Sant GenÃ\xads dels Agudells' 'Montbau' 'la Trinitat Nova'
#  'el Bon Pastor' 'Canyelles' 'Ciutat Meridiana']

# %% [markdown]
# Se traducen los textos de los barrios aun lenguaje legible

# %%
barrios_corregidos = {
    'la Sagrada FamÃ\xadlia': 'La Sagrada Família',
    'el BesÃ²s i el Maresme': 'El Besòs i el Maresme',
    "el Camp d'en Grassot i GrÃ\xa0cia Nova": "El Camp d'en Grassot i Gràcia Nova",
    'el Barri GÃ²tic': 'El Barri Gòtic',
    "la Dreta de l'Eixample": "La Dreta de l'Eixample",
    'Vallcarca i els Penitents': 'Vallcarca i els Penitents',
    'el Raval': 'El Raval',
    'el Poblenou': 'El Poblenou',
    'el Clot': 'El Clot',
    'el Poble Sec': 'El Poble-sec',
    'Sant Antoni': 'Sant Antoni',
    'Sants': 'Sants',
    'Pedralbes': 'Pedralbes',
    'el GuinardÃ³': 'El Guinardó',
    "l'Antiga Esquerra de l'Eixample": "L'Antiga Esquerra de l'Eixample",
    'la Vila de GrÃ\xa0cia': 'La Vila de Gràcia',
    'Diagonal Mar i el Front MarÃ\xadtim del Poblenou': 'Diagonal Mar i el Front Marítim del Poblenou',
    'el Fort Pienc': 'El Fort Pienc',
    'la Barceloneta': 'La Barceloneta',
    'Sant MartÃ\xad de ProvenÃ§als': 'Sant Martí de Provençals',
    "la Nova Esquerra de l'Eixample": "La Nova Esquerra de l'Eixample",
    'SarriÃ\xa0': 'Sarrià',
    'el Parc i la Llacuna del Poblenou': 'El Parc i la Llacuna del Poblenou',
    'Sant Pere, Santa Caterina i la Ribera': 'Sant Pere, Santa Caterina i la Ribera',
    'la Vila OlÃ\xadmpica del Poblenou': 'La Vila Olímpica del Poblenou',
    'les Corts': 'Les Corts',
    'el Putxet i el FarrÃ³': 'El Putxet i el Farró',
    'Sant Gervasi - Galvany': 'Sant Gervasi - Galvany',
    'el CongrÃ©s i els Indians': 'El Congrés i els Indians',
    'la Bordeta': 'La Bordeta',
    'la Maternitat i Sant Ramon': 'La Maternitat i Sant Ramon',
    'ProvenÃ§als del Poblenou': 'Provençals del Poblenou',
    'Sants - Badal': 'Sants - Badal',
    'Navas': 'Navas',
    'el Carmel': 'El Carmel',
    'la Salut': 'La Salut',
    'Hostafrancs': 'Hostafrancs',
    'la Font de la Guatlla': 'La Font de la Guatlla',
    'Sant Gervasi - la Bonanova': 'Sant Gervasi - la Bonanova',
    'les Tres Torres': 'Les Tres Torres',
    'Vallvidrera, el Tibidabo i les Planes': 'Vallvidrera, el Tibidabo i les Planes',
    'la Teixonera': 'La Teixonera',
    'Can BarÃ³': 'Can Baró',
    "el Camp de l'Arpa del Clot": "El Camp de l'Arpa del Clot",
    'la Marina del Prat Vermell': 'La Marina del Prat Vermell',
    'el Baix GuinardÃ³': 'El Baix Guinardó',
    'la Verneda i la Pau': 'La Verneda i la Pau',
    'Porta': 'Porta',
    'Vilapicina i la Torre Llobeta': 'Vilapicina i la Torre Llobeta',
    'el Coll': 'El Coll',
    'la Sagrera': 'La Sagrera',
    'Sant Andreu': 'Sant Andreu',
    "la Font d'en Fargues": "La Font d'en Fargues",
    'la Guineueta': 'La Guineueta',
    'Horta': 'Horta',
    "la Vall d'Hebron": "La Vall d'Hebron",
    'la Prosperitat': 'La Prosperitat',
    'les Roquetes': 'Les Roquetes',
    'la Marina de Port': 'La Marina de Port',
    'el TurÃ³ de la Peira': 'El Turó de la Peira',
    'Can Peguera': 'Can Peguera',
    'Verdun': 'Verdun',
    'la Trinitat Vella': 'La Trinitat Vella',
    'la Clota': 'La Clota',
    'Sant GenÃ\xads dels Agudells': 'Sant Genís dels Agudells',
    'Montbau': 'Montbau',
    'la Trinitat Nova': 'La Trinitat Nova',
    'el Bon Pastor': 'El Bon Pastor',
    'Canyelles': 'Canyelles',
    'Ciutat Meridiana': 'Ciutat Meridiana'
}

df["neighbourhood_cleansed"].replace( barrios_corregidos, inplace=True)
# Out:
# C:\Users\Tomás Otálora\AppData\Local\Temp\ipykernel_16884\2630809960.py:74: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["neighbourhood_cleansed"].replace( barrios_corregidos, inplace=True)

# %% [markdown]
# # Modelo de Predicción del Precio

# %%
#booleanas y enteros
cat_int_feats = ['host_is_superhost','host_listings_count','host_total_listings_count','host_has_profile_pic','accommodates', 'bedrooms', 'beds', 'minimum_nights', 'maximum_nights', 'availability_365', 'number_of_reviews', 'availability_eoy', 'estimated_occupancy_l365d', 'estimated_revenue_l365d', 'instant_bookable', 'calculated_host_listings_count']
#
cat_str_feats = ['neighbourhood_cleansed', 'property_type', 'room_type']

#variables numericas
num_feats = ['host_response_rate', 'host_acceptance_rate', 'latitude', 'longitude', 'review_scores_rating', 'review_scores_accuracy', 'reviews_per_month']

#se quiere estimar el precio

# %%
feats_ordered = cat_int_feats+cat_str_feats+num_feats
df = df[feats_ordered+['price']]
df.head()
# Out:
#    host_is_superhost  host_listings_count  host_total_listings_count  \
# 0                  0                   41                         46
# 1                  1                    6                          9
# 2                  0                    3                         15
# 3                  0                    5                          5
# 4                  0                    5                          5
#
#    host_has_profile_pic  accommodates  bedrooms  beds  minimum_nights  \
# 0                     1             8       3.0   6.0               1
# 1                     1             5       3.0   4.0               3
# 2                     1             6       2.0   3.0               1
# 3                     1             2       1.0   1.0              31
# 4                     1             9       4.0   6.0               5
#
#    maximum_nights  availability_365  ...       property_type        room_type  \
# 0            1125                80  ...  Entire rental unit  Entire home/apt
# 1              32               289  ...  Entire rental unit  Entire home/apt
# 2              31                64  ...  Entire rental unit  Entire home/apt
# 3             180               333  ...        Entire condo  Entire home/apt
# 4             365               335  ...  Entire rental unit  Entire home/apt
#
#    host_response_rate  host_acceptance_rate   latitude  longitude  \
# 0                0.96                  0.91  41.405560    2.17262
# 1                1.00                  0.96  41.412432    2.21975
# 2                1.00                  1.00  41.405660    2.17015
# 3                1.00                  0.92  41.380620    2.17517
# 4                1.00                  0.92  41.379780    2.17623
#
#   review_scores_rating review_scores_accuracy reviews_per_month  price
# 0                 4.34                   4.40              0.34  210.0
# 1                 4.82                   4.94              0.52  285.0
# 2                 4.46                   4.43              0.88  170.0
# 3                 4.36                   4.45              0.14  110.0
# 4                 4.57                   4.61              1.49  333.0
#
# [5 rows x 27 columns]

# %% [markdown]
# Separación De datos de entrenamiento y validación

# %%
train = df.sample(frac=0.8, random_state=100)
print(train.shape)
# Out:
# (11166, 27)

# %%
test = df.drop(train.index)
test.shape
# Out:
# (2791, 27)

# %%
val = train.sample(frac=0.2, random_state=100)
val.shape
# Out:
# (2233, 27)

# %%
def dataframe_to_dataset(dataframe):
    dataframe = dataframe.copy()
    labels = dataframe.pop("price")
    ds = tf.data.Dataset.from_tensor_slices((dict(dataframe), labels))
    ds = ds.shuffle(buffer_size=len(dataframe))
    return ds

train_ds = dataframe_to_dataset(train)
val_ds = dataframe_to_dataset(val)
test_ds = dataframe_to_dataset(test)

# %%
def encode_numerical_feature(feature, name, dataset):
    # Crea capa de normalización para este feature
    normalizer = keras.layers.Normalization()

    # Prepara el dataset para considerar únicamente la feature de interés (name)
    feature_ds = dataset.map(lambda x, y: x[name]) # selecciona variable
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1)) # deja el tensor de una dimensión

    # Aprende las estadísticas de los datos (media, varianza)
    normalizer.adapt(feature_ds)

    # Aplica la normalización a la variable
    encoded_feature = normalizer(feature)
    return encoded_feature

def encode_categorical_feature(feature, name, dataset, is_string):
    lookup_class = keras.layers.StringLookup if is_string else keras.layers.IntegerLookup
    # Crea una capa Lookup para retornas variables 0/1 (dummies)
    # lookup: busca el valor correspondiente de la variable categórica
    lookup = lookup_class(output_mode="binary")

    # Prepara el dataset para considerar únicamente la feature de interés (name)
    feature_ds = dataset.map(lambda x, y: x[name]) # selecciona variable
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1)) # deja el tensor de una dimensión

    # Aprende el conjunto de posibles valores que toma la variable categórica y asigna enteros
    lookup.adapt(feature_ds)

    # Aplica la conversión de categorías a enteros
    encoded_feature = lookup(feature)
    return encoded_feature

# %% [markdown]
# ## Parámetros Red Neuronal

# %%
mlflow.set_tracking_uri('http://localhost:5000')
# registre el experimento
experiment = mlflow.set_experiment("/proyecto2_Pred_Airbnb")
# Out:
# 2025/11/20 14:14:44 INFO mlflow.tracking.fluent: Experiment with name '/proyecto2_Pred_Airbnb' does not exist. Creating a new experiment.

# %%
inputs = []
for i in cat_int_feats:
    inputs.append(keras.Input(shape=(1,), name=i, dtype="int64"))
for i in cat_str_feats:
    inputs.append(keras.Input(shape=(1,), name=i, dtype="string"))
for i in num_feats:
    inputs.append(keras.Input(shape=(1,), name=i))

# Codificación/normalización de features (usa las funciones definidas en el notebook)
feats_encoded = []
for i, feat in enumerate(cat_int_feats):
    feats_encoded.append(encode_categorical_feature(inputs[i], feat, train_ds, False))

len_feats = len(feats_encoded)
for i, feat in enumerate(cat_str_feats):
    feats_encoded.append(encode_categorical_feature(inputs[len_feats + i], feat, train_ds, True))

len_feats = len(feats_encoded)
for i, feat in enumerate(num_feats):
    feats_encoded.append(encode_numerical_feature(inputs[len_feats + i], feat, train_ds))

# Concatenar todas las features codificadas
all_feats = keras.layers.concatenate(feats_encoded)

# %%
#mlflow.end_run()
n_epochs = 10
learning_rate = 0.05
num_hidden_units = 64
num_hidden_layers = 5
batch_size = 32

def run_mlflow_model(run_name="Mlflow_modelo_Airbnb_pred",
                     n_epochs=n_epochs,
                     learning_rate=learning_rate,
                     num_hidden_units=num_hidden_units,
                     num_hidden_layers=num_hidden_layers,
                     batch_size=batch_size):
    """
    Construye y entrena un modelo usando la estructura de 'actd_redes' y registra parámetros/ejecución en MLflow.
    Requiere que existan en el scope: cat_int_feats, cat_str_feats, num_feats, train_ds, val_ds, encode_* funciones.
    """
    mlflow.start_run(run_name=run_name)
    mlflow.log_param("epocas", n_epochs)
    mlflow.log_param("learning_rate", learning_rate)
    mlflow.log_param("num_hidden_units", num_hidden_units)
    mlflow.log_param("num_hidden_layers", num_hidden_layers)
    mlflow.log_param("batch_size", batch_size)
    mlflow.keras.autolog()

    # Capas ocultas según parámetros
    x = all_feats
    for _ in range(int(num_hidden_layers)):
        x = keras.layers.Dense(int(num_hidden_units), activation='relu')(x)

    # Neurona de salida con relu
    outputs = keras.layers.Dense(1, activation='relu')(x)

    model = keras.Model(inputs=inputs, outputs=outputs)

    # Optimizador con learning_rate pasado
    optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='mean_absolute_error', metrics= ['mse'])

    # Ajustar batch size en los tf.data.Dataset antes del entrenamiento
    train_ds_batched = train_ds.batch(batch_size)
    val_ds_batched = val_ds.batch(batch_size)

    # Entrenamiento (usa los tf.data.Dataset existentes: train_ds_batched y val_ds_batched)
    history = model.fit(train_ds_batched, validation_data=val_ds_batched, epochs=int(n_epochs))

    mlflow.log_metric("mse", history.history['val_mse'][-1])  

    mlflow.end_run(status='FINISHED')
    return model, history

# %%
#mlflow.end_run()

#MEJOR 

"""
n_epochs = 50
learning_rate = 0.001
num_hidden_units = 64
num_hidden_layers = 5
batch_size = 32

"""
n_epochs = 500
learning_rate = 0.001
num_hidden_units = 64
num_hidden_layers = 5
batch_size = 32

# %%
(experimentID, runID) = run_mlflow_model("Mlflow_modelo_Airbnb_pred", n_epochs,  learning_rate, num_hidden_units, num_hidden_layers, batch_size)
print("MLflow Run completed with run_id {} and experiment_id {}".format(runID, experimentID))
# Out:
# 2025/11/20 14:17:27 WARNING mlflow.keras.autologging: Failed to log dataset information to MLflow. Reason: 'ascii' codec can't decode byte 0xc3 in position 10: ordinal not in range(128)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Epoch 1/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 89.5367 - mse: 112436.9531 - val_loss: 58.0281 - val_mse: 73358.0859
# Epoch 2/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 61.8515 - mse: 96537.1641 - val_loss: 51.9794 - val_mse: 65895.6562
# Epoch 3/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 54.7012 - mse: 90408.7891 - val_loss: 44.1545 - val_mse: 61929.7930
# Epoch 4/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 49.1468 - mse: 86333.4766 - val_loss: 39.4968 - val_mse: 59795.0352
# Epoch 5/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 44.6927 - mse: 82856.2109 - val_loss: 37.1989 - val_mse: 56598.7188
# Epoch 6/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 41.7164 - mse: 79201.8516 - val_loss: 34.1069 - val_mse: 53521.6094
# Epoch 7/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 39.2805 - mse: 75488.5625 - val_loss: 32.4082 - val_mse: 50702.7266
# Epoch 8/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 36.9662 - mse: 72243.8906 - val_loss: 30.1356 - val_mse: 48733.6602
# Epoch 9/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 34.6351 - mse: 69326.6953 - val_loss: 28.9850 - val_mse: 45851.2695
# Epoch 10/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 33.4734 - mse: 66220.6797 - val_loss: 27.6871 - val_mse: 43520.0078
# Epoch 11/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 31.6019 - mse: 61619.8555 - val_loss: 26.1001 - val_mse: 39187.7734
# Epoch 12/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 30.2902 - mse: 55947.4297 - val_loss: 26.4923 - val_mse: 35470.1250
# Epoch 13/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 28.3504 - mse: 49511.5039 - val_loss: 22.7140 - val_mse: 29133.6699
# Epoch 14/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 26.6159 - mse: 42868.8320 - val_loss: 24.3497 - val_mse: 25171.2109
# Epoch 15/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 25.1019 - mse: 36095.8672 - val_loss: 23.8111 - val_mse: 19783.8594
# Epoch 16/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 23.1531 - mse: 30295.5430 - val_loss: 20.7332 - val_mse: 16358.0244
# Epoch 17/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 22.0603 - mse: 27182.5391 - val_loss: 18.1614 - val_mse: 13663.0039
# Epoch 18/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 20.9877 - mse: 24836.4766 - val_loss: 17.7889 - val_mse: 13728.4873
# Epoch 19/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 19.6912 - mse: 22953.8242 - val_loss: 18.0746 - val_mse: 13563.9141
# Epoch 20/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 19.0975 - mse: 22133.9102 - val_loss: 16.2329 - val_mse: 13505.4756
# Epoch 21/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 18.6499 - mse: 20718.2012 - val_loss: 16.4011 - val_mse: 13909.9775
# Epoch 22/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 18.2672 - mse: 19869.4043 - val_loss: 15.6653 - val_mse: 13244.2725
# Epoch 23/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 17.2979 - mse: 18162.5781 - val_loss: 14.2352 - val_mse: 12790.5371
# Epoch 24/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 16.4550 - mse: 17658.8008 - val_loss: 15.8699 - val_mse: 12940.7100
# Epoch 25/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 16.5958 - mse: 16832.8828 - val_loss: 16.8506 - val_mse: 14889.5078
# Epoch 26/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 16.6896 - mse: 16725.6660 - val_loss: 13.8621 - val_mse: 12762.5020
# Epoch 27/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 15.7173 - mse: 14940.0879 - val_loss: 16.3719 - val_mse: 13499.9150
# Epoch 28/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 15.2780 - mse: 14619.0244 - val_loss: 16.3348 - val_mse: 13108.1152
# Epoch 29/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 15.4964 - mse: 13803.1113 - val_loss: 15.0078 - val_mse: 13324.4121
# Epoch 30/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 15.0074 - mse: 13554.3633 - val_loss: 15.7319 - val_mse: 14175.0400
# Epoch 31/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 14.2839 - mse: 13233.4443 - val_loss: 14.5669 - val_mse: 12772.9697
# Epoch 32/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 14.2952 - mse: 13033.2578 - val_loss: 14.2822 - val_mse: 13301.5879
# Epoch 33/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 13.6947 - mse: 12251.0176 - val_loss: 14.4180 - val_mse: 13367.1602
# Epoch 34/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 14.0815 - mse: 12667.5664 - val_loss: 13.1331 - val_mse: 12613.7070
# Epoch 35/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 13.5506 - mse: 12013.8877 - val_loss: 12.7951 - val_mse: 12819.3506
# Epoch 36/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 12.9625 - mse: 11920.8330 - val_loss: 14.3152 - val_mse: 13031.0166
# Epoch 37/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 12.9910 - mse: 11450.2109 - val_loss: 13.1321 - val_mse: 13063.0283
# Epoch 38/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 12.8730 - mse: 11395.1055 - val_loss: 13.3499 - val_mse: 12659.7246
# Epoch 39/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 12.5986 - mse: 11431.9121 - val_loss: 12.7264 - val_mse: 12496.8398
# Epoch 40/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 12.6206 - mse: 11278.6240 - val_loss: 12.9131 - val_mse: 12928.4395
# Epoch 41/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 12.2443 - mse: 11464.2881 - val_loss: 13.2512 - val_mse: 12295.8330
# Epoch 42/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 12.3375 - mse: 11179.7510 - val_loss: 13.8653 - val_mse: 12408.4297
# Epoch 43/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 12.0842 - mse: 11138.9854 - val_loss: 12.6998 - val_mse: 12518.4453
# Epoch 44/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 11.8171 - mse: 11244.5146 - val_loss: 12.1646 - val_mse: 12416.5449
# Epoch 45/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 11.8461 - mse: 11338.5410 - val_loss: 11.5745 - val_mse: 12374.5146
# Epoch 46/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 11.9839 - mse: 11183.3604 - val_loss: 14.1541 - val_mse: 13280.1025
# Epoch 47/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 11.7743 - mse: 11200.9004 - val_loss: 12.3364 - val_mse: 12650.9414
# Epoch 48/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 11.8266 - mse: 10940.6143 - val_loss: 11.1592 - val_mse: 12140.6348
# Epoch 49/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 11.6140 - mse: 10866.1865 - val_loss: 10.5944 - val_mse: 11930.8848
# Epoch 50/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 11.1252 - mse: 10839.3018 - val_loss: 13.0303 - val_mse: 13088.8955
# Epoch 51/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 11.4235 - mse: 11101.5449 - val_loss: 11.6903 - val_mse: 11907.0518
# Epoch 52/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 10.9907 - mse: 10626.4834 - val_loss: 11.8902 - val_mse: 12377.3945
# Epoch 53/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 11.1739 - mse: 10867.9365 - val_loss: 10.7488 - val_mse: 11858.0967
# Epoch 54/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 10.8493 - mse: 10666.6289 - val_loss: 12.2336 - val_mse: 12480.0605
# Epoch 55/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 11.1116 - mse: 10809.3262 - val_loss: 12.7890 - val_mse: 12146.9355
# Epoch 56/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 10.9369 - mse: 10668.2471 - val_loss: 10.6934 - val_mse: 11992.2344
# Epoch 57/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 10.7889 - mse: 10694.3936 - val_loss: 10.7514 - val_mse: 11994.1279
# Epoch 58/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 10.5237 - mse: 10571.6543 - val_loss: 16.9709 - val_mse: 12549.9941
# Epoch 59/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 10.9300 - mse: 10682.7012 - val_loss: 10.1120 - val_mse: 11580.9512
# Epoch 60/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 10.6474 - mse: 10470.7178 - val_loss: 10.3793 - val_mse: 11926.3477
# Epoch 61/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 10.6956 - mse: 10602.3926 - val_loss: 12.2621 - val_mse: 12491.9619
# Epoch 62/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 10.4392 - mse: 10549.4404 - val_loss: 10.7144 - val_mse: 11642.2539
# Epoch 63/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 10.2667 - mse: 10450.8691 - val_loss: 10.5139 - val_mse: 11470.4756
# Epoch 64/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 10.2858 - mse: 10417.5771 - val_loss: 10.3121 - val_mse: 11537.2383
# Epoch 65/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 10.3060 - mse: 10318.5664 - val_loss: 9.6448 - val_mse: 11070.4883
# Epoch 66/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 10.1212 - mse: 10096.2725 - val_loss: 9.6063 - val_mse: 11074.6221
# Epoch 67/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 10.1722 - mse: 10330.4072 - val_loss: 9.8398 - val_mse: 11250.7783
# Epoch 68/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 9.8804 - mse: 10146.4482 - val_loss: 11.2067 - val_mse: 11217.3818
# Epoch 69/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 10.0218 - mse: 10264.9004 - val_loss: 10.1648 - val_mse: 11155.9141
# Epoch 70/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 9.5931 - mse: 10422.1826 - val_loss: 9.9070 - val_mse: 11136.0615
# Epoch 71/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 9.6030 - mse: 10195.4766 - val_loss: 11.1304 - val_mse: 11545.3965
# Epoch 72/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 9.7481 - mse: 10195.2725 - val_loss: 10.1212 - val_mse: 11113.7441
# Epoch 73/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 9.6570 - mse: 10012.5566 - val_loss: 10.0997 - val_mse: 11013.2744
# Epoch 74/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 9.5546 - mse: 10129.3945 - val_loss: 9.2359 - val_mse: 10898.7686
# Epoch 75/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 9.1339 - mse: 9815.9775 - val_loss: 10.8649 - val_mse: 11221.3750
# Epoch 76/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 9.5671 - mse: 9956.5244 - val_loss: 9.8695 - val_mse: 11015.6650
# Epoch 77/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 9.3036 - mse: 9780.3965 - val_loss: 9.6234 - val_mse: 10625.7607
# Epoch 78/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 9.0268 - mse: 9722.1211 - val_loss: 8.9779 - val_mse: 10710.3242
# Epoch 79/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 9.4972 - mse: 9750.2637 - val_loss: 9.8978 - val_mse: 10604.9570
# Epoch 80/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 9.1678 - mse: 9480.6221 - val_loss: 10.2693 - val_mse: 10796.0664
# Epoch 81/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 9.2632 - mse: 9577.7812 - val_loss: 8.7696 - val_mse: 10285.0713
# Epoch 82/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 8.9883 - mse: 9481.6953 - val_loss: 9.3445 - val_mse: 10443.2012
# Epoch 83/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 8.9843 - mse: 9269.2656 - val_loss: 9.1992 - val_mse: 10396.9951
# Epoch 84/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 8.9807 - mse: 9372.7773 - val_loss: 11.4344 - val_mse: 10509.8574
# Epoch 85/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 8.9990 - mse: 9208.5879 - val_loss: 9.1281 - val_mse: 10479.6250
# Epoch 86/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 9.0220 - mse: 9153.8174 - val_loss: 8.4234 - val_mse: 10218.9209
# Epoch 87/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 8.5603 - mse: 8757.2119 - val_loss: 9.1377 - val_mse: 9622.8496
# Epoch 88/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 8.8338 - mse: 8630.0059 - val_loss: 9.6652 - val_mse: 10029.7617
# Epoch 89/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 8
500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 6.8894 - mse: 1257.5575 - val_loss: 6.3466 - val_mse: 1765.3245
# Epoch 122/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 6.7727 - mse: 1143.8740 - val_loss: 6.5304 - val_mse: 1815.5780
# Epoch 123/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 6.8162 - mse: 1341.3887 - val_loss: 5.9832 - val_mse: 1408.9722
# Epoch 124/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 6.8134 - mse: 1226.1724 - val_loss: 7.0866 - val_mse: 1836.9467
# Epoch 125/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 6.4751 - mse: 1079.8726 - val_loss: 8.4155 - val_mse: 1440.1450
# Epoch 126/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 6.4734 - mse: 1168.8643 - val_loss: 6.3358 - val_mse: 1396.9918
# Epoch 127/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 6.6840 - mse: 1135.0204 - val_loss: 6.5751 - val_mse: 1405.8910
# Epoch 128/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 6.7790 - mse: 1103.6337 - val_loss: 5.5766 - val_mse: 887.8527
# Epoch 129/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 6.3636 - mse: 917.5928 - val_loss: 6.8313 - val_mse: 811.5016
# Epoch 130/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 6.7890 - mse: 1105.8955 - val_loss: 5.1817 - val_mse: 732.7850
# Epoch 131/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 6.3636 - mse: 943.8505 - val_loss: 5.9426 - val_mse: 728.4948
# Epoch 132/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 6.5880 - mse: 1002.7197 - val_loss: 5.6712 - val_mse: 1149.3055
# Epoch 133/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 6.2956 - mse: 1031.7795 - val_loss: 5.7861 - val_mse: 694.9369
# Epoch 134/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 6.5891 - mse: 1033.8344 - val_loss: 7.5337 - val_mse: 1165.7114
# Epoch 135/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 6.4079 - mse: 1039.4006 - val_loss: 8.1742 - val_mse: 769.9907
# Epoch 136/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 7.0101 - mse: 1049.8926 - val_loss: 5.1582 - val_mse: 443.2109
# Epoch 137/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 6.8498 - mse: 1159.8124 - val_loss: 5.7676 - val_mse: 812.9094
# Epoch 138/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 6.2067 - mse: 844.8970 - val_loss: 5.7893 - val_mse: 661.0544
# Epoch 139/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 6.3226 - mse: 882.4756 - val_loss: 5.2440 - val_mse: 420.0554
# Epoch 140/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.3296 - mse: 972.3765 - val_loss: 5.4931 - val_mse: 473.0811
# Epoch 141/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 6.2196 - mse: 806.7150 - val_loss: 5.9249 - val_mse: 407.3501
# Epoch 142/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 6.5681 - mse: 979.8345 - val_loss: 5.2139 - val_mse: 271.7328
# Epoch 143/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.0345 - mse: 798.7497 - val_loss: 5.0092 - val_mse: 267.6490
# Epoch 144/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 6.5347 - mse: 965.6879 - val_loss: 5.1045 - val_mse: 260.1330
# Epoch 145/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 5.9433 - mse: 763.3745 - val_loss: 5.5132 - val_mse: 336.2559
# Epoch 146/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 6.0544 - mse: 890.2482 - val_loss: 4.5223 - val_mse: 146.5382
# Epoch 147/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 6.0742 - mse: 849.8093 - val_loss: 5.2750 - val_mse: 375.7271
# Epoch 148/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 6.1642 - mse: 823.9276 - val_loss: 5.3684 - val_mse: 642.9634
# Epoch 149/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 5.9779 - mse: 684.5524 - val_loss: 4.4133 - val_mse: 97.5248
# Epoch 150/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 5.9690 - mse: 847.3334 - val_loss: 4.8611 - val_mse: 184.4528
# Epoch 151/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 5.6624 - mse: 652.6810 - val_loss: 4.9160 - val_mse: 290.8004
# Epoch 152/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 6.0264 - mse: 778.4471 - val_loss: 5.8585 - val_mse: 233.7834
# Epoch 153/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 6.1018 - mse: 845.8770 - val_loss: 5.1073 - val_mse: 475.4640
# Epoch 154/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 6.0880 - mse: 964.2236 - val_loss: 5.2578 - val_mse: 236.9892
# Epoch 155/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 6.1597 - mse: 904.1267 - val_loss: 4.5673 - val_mse: 320.1978
# Epoch 156/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 5.6715 - mse: 716.7414 - val_loss: 6.1261 - val_mse: 405.7442
# Epoch 157/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 5.9255 - mse: 705.1843 - val_loss: 6.2497 - val_mse: 434.9111
# Epoch 158/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 6.0793 - mse: 792.0857 - val_loss: 5.2536 - val_mse: 394.9211
# Epoch 159/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 6.0324 - mse: 847.1050 - val_loss: 4.9866 - val_mse: 220.1762
# Epoch 160/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 6.1347 - mse: 759.1150 - val_loss: 4.7027 - val_mse: 222.7455
# Epoch 161/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 5.6621 - mse: 617.0003 - val_loss: 5.3490 - val_mse: 302.8841
# Epoch 162/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 5.7677 - mse: 869.3412 - val_loss: 4.6874 - val_mse: 384.4488
# Epoch 163/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 5.8183 - mse: 798.2401 - val_loss: 4.7576 - val_mse: 147.9201
# Epoch 164/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 5.5961 - mse: 727.8128 - val_loss: 4.6775 - val_mse: 287.7556
# Epoch 165/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 5.6933 - mse: 806.3102 - val_loss: 5.6731 - val_mse: 454.7723
# Epoch 166/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 5.7660 - mse: 714.3990 - val_loss: 5.1103 - val_mse: 538.7947
# Epoch 167/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 5.7679 - mse: 768.9401 - val_loss: 5.6288 - val_mse: 325.7545
# Epoch 168/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 5.5223 - mse: 679.3476 - val_loss: 5.7263 - val_mse: 612.9462
# Epoch 169/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 5.4917 - mse: 710.0075 - val_loss: 4.6539 - val_mse: 217.3235
# Epoch 170/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 5.4839 - mse: 679.8762 - val_loss: 4.7339 - val_mse: 379.1929
# Epoch 171/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 5.8397 - mse: 793.8534 - val_loss: 4.5121 - val_mse: 239.7110
# Epoch 172/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 5.4120 - mse: 527.5534 - val_loss: 4.8858 - val_mse: 466.7218
# Epoch 173/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 5.8480 - mse: 850.9764 - val_loss: 4.9284 - val_mse: 268.6863
# Epoch 174/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 5.4927 - mse: 708.9349 - val_loss: 4.7034 - val_mse: 289.3067
# Epoch 175/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 5.5479 - mse: 757.1920 - val_loss: 4.4385 - val_mse: 215.5017
# Epoch 176/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 5.3613 - mse: 527.6607 - val_loss: 4.6300 - val_mse: 301.4964
# Epoch 177/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 5.3754 - mse: 531.1639 - val_loss: 4.1742 - val_mse: 325.2407
# Epoch 178/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 5.4038 - mse: 680.5576 - val_loss: 5.0875 - val_mse: 531.9222
# Epoch 179/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 5.5695 - mse: 618.3518 - val_loss: 4.7083 - val_mse: 131.3044
# Epoch 180/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 5.5139 - mse: 720.3432 - val_loss: 4.6036 - val_mse: 393.9967
# Epoch 181/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 5.7150 - mse: 615.9567 - val_loss: 5.3257 - val_mse: 328.6306
# Epoch 182/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 5.6903 - mse: 617.1319 - val_loss: 4.4155 - val_mse: 338.2697
# Epoch 183/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 5.5369 - mse: 698.5298 - val_loss: 4.5997 - val_mse: 160.4552
# Epoch 184/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 5.4185 - mse: 540.2701 - val_loss: 4.5300 - val_mse: 347.4032
# Epoch 185/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 5.5736 - mse: 694.1880 - val_loss: 4.2922 - val_mse: 185.6357
# Epoch 186/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 5.
500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 4.5440 - mse: 511.3632 - val_loss: 3.9323 - val_mse: 143.9933
# Epoch 254/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 4.7325 - mse: 465.7148 - val_loss: 4.5189 - val_mse: 298.4898
# Epoch 255/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 4.4104 - mse: 287.5789 - val_loss: 3.9726 - val_mse: 393.9403
# Epoch 256/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 4.6201 - mse: 410.8100 - val_loss: 4.4318 - val_mse: 404.1947
# Epoch 257/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 4.5827 - mse: 475.1573 - val_loss: 3.6047 - val_mse: 113.8518
# Epoch 258/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 4.5544 - mse: 399.4137 - val_loss: 4.7990 - val_mse: 298.7750
# Epoch 259/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 4.4429 - mse: 367.0468 - val_loss: 4.2987 - val_mse: 514.1893
# Epoch 260/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 4.6088 - mse: 468.6247 - val_loss: 3.8079 - val_mse: 124.9131
# Epoch 261/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 4.3713 - mse: 331.9303 - val_loss: 4.7161 - val_mse: 499.1271
# Epoch 262/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 4.6321 - mse: 384.6089 - val_loss: 3.9231 - val_mse: 105.8143
# Epoch 263/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 4.5640 - mse: 381.0339 - val_loss: 4.8132 - val_mse: 176.4728
# Epoch 264/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 4.5571 - mse: 492.9998 - val_loss: 3.9204 - val_mse: 167.2444
# Epoch 265/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 4.3156 - mse: 320.7361 - val_loss: 3.8273 - val_mse: 298.4813
# Epoch 266/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 4.6198 - mse: 399.2124 - val_loss: 4.0153 - val_mse: 226.8509
# Epoch 267/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 4.4353 - mse: 441.4233 - val_loss: 3.6446 - val_mse: 232.9248
# Epoch 268/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 4.4518 - mse: 417.1544 - val_loss: 3.7756 - val_mse: 184.9737
# Epoch 269/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 4.4900 - mse: 349.2689 - val_loss: 4.3877 - val_mse: 284.8583
# Epoch 270/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 4.4659 - mse: 366.6416 - val_loss: 4.1529 - val_mse: 419.3886
# Epoch 271/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 4.2457 - mse: 288.6821 - val_loss: 3.7847 - val_mse: 149.3798
# Epoch 272/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 4.5418 - mse: 434.4227 - val_loss: 3.3838 - val_mse: 103.2465
# Epoch 273/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 4.3311 - mse: 366.7394 - val_loss: 3.9120 - val_mse: 161.2303
# Epoch 274/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 4.1783 - mse: 306.4825 - val_loss: 4.0967 - val_mse: 166.0940
# Epoch 275/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 4.2238 - mse: 302.8832 - val_loss: 4.1459 - val_mse: 144.7430
# Epoch 276/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 4.2483 - mse: 348.3124 - val_loss: 3.6583 - val_mse: 286.1077
# Epoch 277/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 4.3054 - mse: 315.7026 - val_loss: 4.2458 - val_mse: 248.3085
# Epoch 278/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 4.5114 - mse: 400.1986 - val_loss: 3.4998 - val_mse: 109.5446
# Epoch 279/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 4.4728 - mse: 345.1005 - val_loss: 3.4505 - val_mse: 106.7086
# Epoch 280/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 4.2201 - mse: 275.8642 - val_loss: 4.0037 - val_mse: 272.9588
# Epoch 281/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 4.1827 - mse: 341.1072 - val_loss: 3.9603 - val_mse: 261.2939
# Epoch 282/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 4.4096 - mse: 424.1507 - val_loss: 3.8168 - val_mse: 129.0849
# Epoch 283/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 4.4057 - mse: 282.0332 - val_loss: 3.7417 - val_mse: 132.7676
# Epoch 284/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 4.5421 - mse: 404.6185 - val_loss: 3.8381 - val_mse: 130.0697
# Epoch 285/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 4.3515 - mse: 323.9483 - val_loss: 4.1669 - val_mse: 211.0058
# Epoch 286/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 4.
500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 4.1359 - mse: 328.2421 - val_loss: 3.7683 - val_mse: 184.9693
# Epoch 321/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 4.2114 - mse: 305.7109 - val_loss: 3.8101 - val_mse: 544.1768
# Epoch 322/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.8977 - mse: 292.1576 - val_loss: 3.3211 - val_mse: 114.6918
# Epoch 323/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 4.0853 - mse: 326.7105 - val_loss: 3.9174 - val_mse: 124.5338
# Epoch 324/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 4.0341 - mse: 254.0752 - val_loss: 4.4063 - val_mse: 161.5391
# Epoch 325/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.9925 - mse: 256.7523 - val_loss: 3.3446 - val_mse: 164.8246
# Epoch 326/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.9935 - mse: 341.8730 - val_loss: 3.5200 - val_mse: 163.0116
# Epoch 327/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.7972 - mse: 236.8753 - val_loss: 4.2564 - val_mse: 176.1820
# Epoch 328/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 4.0620 - mse: 289.1446 - val_loss: 3.6900 - val_mse: 209.3450
# Epoch 329/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.9199 - mse: 251.2582 - val_loss: 3.7856 - val_mse: 230.4263
# Epoch 330/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 4.1517 - mse: 324.9553 - val_loss: 3.5070 - val_mse: 252.9188
# Epoch 331/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 4.0068 - mse: 221.8199 - val_loss: 3.3941 - val_mse: 181.0356
# Epoch 332/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.9654 - mse: 282.6786 - val_loss: 3.3464 - val_mse: 184.2052
# Epoch 333/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.9124 - mse: 216.3499 - val_loss: 3.4665 - val_mse: 134.4256
# Epoch 334/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 4.0786 - mse: 278.3751 - val_loss: 4.3088 - val_mse: 321.1650
# Epoch 335/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 4.0806 - mse: 274.4836 - val_loss: 3.9770 - val_mse: 236.8688
# Epoch 336/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 4.0155 - mse: 272.3730 - val_loss: 3.8574 - val_mse: 164.3528
# Epoch 337/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.8981 - mse: 344.7811 - val_loss: 3.7410 - val_mse: 107.0467
# Epoch 338/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.9555 - mse: 244.4042 - val_loss: 3.4376 - val_mse: 287.9439
# Epoch 339/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 4.0267 - mse: 322.6330 - val_loss: 3.9279 - val_mse: 218.4025
# Epoch 340/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.9004 - mse: 214.9332 - val_loss: 3.4609 - val_mse: 235.4721
# Epoch 341/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.8803 - mse: 260.5564 - val_loss: 3.5176 - val_mse: 260.3100
# Epoch 342/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.9286 - mse: 242.0756 - val_loss: 4.2152 - val_mse: 788.4707
# Epoch 343/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.8956 - mse: 255.2426 - val_loss: 3.3080 - val_mse: 208.0223
# Epoch 344/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 4.0172 - mse: 260.7722 - val_loss: 3.5019 - val_mse: 330.0728
# Epoch 345/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 4.0170 - mse: 281.8554 - val_loss: 3.9341 - val_mse: 190.4358
# Epoch 346/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 3.9177 - mse: 233.2474 - val_loss: 3.2505 - val_mse: 147.1532
# Epoch 347/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 3.9954 - mse: 206.2682 - val_loss: 3.8838 - val_mse: 266.2513
# Epoch 348/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 3.9533 - mse: 254.9312 - val_loss: 3.3289 - val_mse: 181.3948
# Epoch 349/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 3.7485 - mse: 178.9591 - val_loss: 3.1255 - val_mse: 99.8657
# Epoch 350/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 3.9076 - mse: 335.8798 - val_loss: 4.9346 - val_mse: 314.2689
# Epoch 351/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 3.8231 - mse: 205.0718 - val_loss: 3.3780 - val_mse: 124.2804
# Epoch 352/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.7966 - mse: 215.6819 - val_loss: 3.3070 - val_mse: 156.7339
# Epoch 353/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3
500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.3980 - mse: 155.1544 - val_loss: 3.3866 - val_mse: 76.7860
# Epoch 391/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.6151 - mse: 212.8348 - val_loss: 3.3203 - val_mse: 232.4521
# Epoch 392/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.7814 - mse: 266.8230 - val_loss: 3.0356 - val_mse: 144.3535
# Epoch 393/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.7110 - mse: 211.9803 - val_loss: 3.5267 - val_mse: 135.1525
# Epoch 394/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.7268 - mse: 242.3179 - val_loss: 2.8790 - val_mse: 66.2571
# Epoch 395/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.6436 - mse: 203.9716 - val_loss: 3.0390 - val_mse: 90.0938
# Epoch 396/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 3.6329 - mse: 219.5455 - val_loss: 3.0277 - val_mse: 102.0629
# Epoch 397/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.5275 - mse: 161.3926 - val_loss: 3.0694 - val_mse: 68.7460
# Epoch 398/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.6137 - mse: 269.9070 - val_loss: 3.9389 - val_mse: 153.4191
# Epoch 399/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.5544 - mse: 224.5315 - val_loss: 2.8165 - val_mse: 77.3986
# Epoch 400/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.4707 - mse: 217.0057 - val_loss: 3.4080 - val_mse: 148.6059
# Epoch 401/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.5575 - mse: 204.5651 - val_loss: 3.5882 - val_mse: 104.5448
# Epoch 402/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.4693 - mse: 174.7014 - val_loss: 3.2476 - val_mse: 159.4465
# Epoch 403/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 3.6027 - mse: 190.4551 - val_loss: 3.3626 - val_mse: 196.1340
# Epoch 404/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.6359 - mse: 209.6023 - val_loss: 3.0374 - val_mse: 76.8112
# Epoch 405/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.4695 - mse: 217.4286 - val_loss: 3.1246 - val_mse: 100.8445
# Epoch 406/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 3.5594 - mse: 213.5034 - val_loss: 3.5374 - val_mse: 321.5663
# Epoch 407/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.4655 - mse: 206.4647 - val_loss: 3.2664 - val_mse: 182.8133
# Epoch 408/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 3.5024 - mse: 183.8299 - val_loss: 3.8505 - val_mse: 205.5497
# Epoch 409/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 3.8659 - mse: 244.8041 - val_loss: 3.1284 - val_mse: 136.2966
# Epoch 410/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.5102 - mse: 194.1839 - val_loss: 3.1972 - val_mse: 142.7915
# Epoch 411/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.6226 - mse: 224.3664 - val_loss: 3.1415 - val_mse: 158.9655
# Epoch 412/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.4336 - mse: 185.2135 - val_loss: 4.5477 - val_mse: 164.7181
# Epoch 413/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.6280 - mse: 198.7209 - val_loss: 3.5491 - val_mse: 151.5755
# Epoch 414/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 3.5121 - mse: 152.3323 - val_loss: 3.4239 - val_mse: 137.7272
# Epoch 415/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.6062 - mse: 187.0277 - val_loss: 3.8896 - val_mse: 182.4666
# Epoch 416/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 3.7254 - mse: 255.6708 - val_loss: 3.7259 - val_mse: 103.3536
# Epoch 417/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.6243 - mse: 193.6408 - val_loss: 3.1344 - val_mse: 149.0013
# Epoch 418/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.5766 - mse: 188.1394 - val_loss: 3.6657 - val_mse: 162.9390
# Epoch 419/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 3.4715 - mse: 166.7607 - val_loss: 3.2020 - val_mse: 215.9915
# Epoch 420/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.7191 - mse: 292.1515 - val_loss: 4.1808 - val_mse: 213.9893
# Epoch 421/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.4982 - mse: 195.6593 - val_loss: 2.9155 - val_mse: 132.7205
# Epoch 422/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.4933 - mse: 206.1371 - val_loss: 3.5109 - val_mse: 191.9472
# Epoch 423/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.3937 - mse: 192.8352 - val_loss: 4.6229 - val_mse: 121.6190
# Epoch 424/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.3542 - mse: 205.1866 - val_loss: 2.8412 - val_mse: 106.1602
# Epoch 425/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 3.3977 - mse: 147.3544 - val_loss: 3.1847 - val_mse: 284.5311
# Epoch 426/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.6704 - mse: 202.8849 - val_loss: 3.2086 - val_mse: 206.3330
# Epoch 427/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 3.5939 - mse: 247.5273 - val_loss: 3.1077 - val_mse: 131.2389
# Epoch 428/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.6092 - mse: 224.8746 - val_loss: 3.8156 - val_mse: 169.3379
# Epoch 429/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 3.4605 - mse: 156.8151 - val_loss: 2.9134 - val_mse: 177.7614
# Epoch 430/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.4476 - mse: 237.4230 - val_loss: 3.7526 - val_mse: 195.9296
# Epoch 431/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.2913 - mse: 149.7288 - val_loss: 2.9701 - val_mse: 145.1234
# Epoch 432/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.5030 - mse: 256.2012 - val_loss: 3.8757 - val_mse: 176.7205
# Epoch 433/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.5682 - mse: 219.0614 - val_loss: 3.7832 - val_mse: 203.2929
# Epoch 434/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.4372 - mse: 233.4029 - val_loss: 3.0978 - val_mse: 134.5532
# Epoch 435/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 3.4985 - mse: 197.3390 - val_loss: 3.5510 - val_mse: 181.2705
# Epoch 436/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.5336 - mse: 201.1634 - val_loss: 3.3725 - val_mse: 119.3881
# Epoch 437/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.5373 - mse: 215.5403 - val_loss: 3.5372 - val_mse: 103.9788
# Epoch 438/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.6311 - mse: 247.1653 - val_loss: 2.8588 - val_mse: 104.9295
# Epoch 439/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.4711 - mse: 187.9471 - val_loss: 3.3583 - val_mse: 135.6010
# Epoch 440/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.2406 - mse: 149.2439 - val_loss: 3.9865 - val_mse: 291.1935
# Epoch 441/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.4173 - mse: 188.6012 - val_loss: 3.0750 - val_mse: 77.0660
# Epoch 442/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.5874 - mse: 230.8112 - val_loss: 3.2421 - val_mse: 135.3419
# Epoch 443/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.5404 - mse: 220.5352 - val_loss: 4.6922 - val_mse: 296.2043
# Epoch 444/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 3.5132 - mse: 207.4835 - val_loss: 2.8461 - val_mse: 133.5728
# Epoch 445/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.4348 - mse: 180.3855 - val_loss: 2.7305 - val_mse: 67.8686
# Epoch 446/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.3587 - mse: 155.4740 - val_loss: 3.0184 - val_mse: 160.4834
# Epoch 447/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.4813 - mse: 248.2107 - val_loss: 2.9314 - val_mse: 112.3876
# Epoch 448/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.5205 - mse: 171.7224 - val_loss: 3.1970 - val_mse: 109.8380
# Epoch 449/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.4787 - mse: 303.6939 - val_loss: 2.8127 - val_mse: 142.7666
# Epoch 450/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.4258 - mse: 199.1377 - val_loss: 3.5349 - val_mse: 92.6005
# Epoch 451/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.2642 - mse: 177.8554 - val_loss: 2.8385 - val_mse: 85.4438
# Epoch 452/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.3841 - mse: 222.9836 - val_loss: 3.0987 - val_mse: 174.7625
# Epoch 453/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.4512 - mse: 194.2458 - val_loss: 3.5849 - val_mse: 108.6510
# Epoch 454/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.3731 - mse: 190.6715 - val_loss: 2.8699 - val_mse: 132.5969
# Epoch 455/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.5248 - mse: 180.3466 - val_loss: 3.3737 - val_mse: 214.1518
# Epoch 456/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.3236 - mse: 209.0179 - val_loss: 3.3185 - val_mse: 199.2501
# Epoch 457/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 3.4203 - mse: 199.6589 - val_loss: 3.3200 - val_mse: 130.8528
# Epoch 458/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.5044 - mse: 165.4393 - val_loss: 4.8367 - val_mse: 254.1344
# Epoch 459/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.4061 - mse: 151.7132 - val_loss: 3.1408 - val_mse: 69.8302
# Epoch 460/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.4697 - mse: 194.4779 - val_loss: 2.8611 - val_mse: 206.6591
# Epoch 461/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 3.4785 - mse: 197.5962 - val_loss: 2.6248 - val_mse: 44.5997
# Epoch 462/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 3.3086 - mse: 173.0654 - val_loss: 3.0788 - val_mse: 82.2088
# Epoch 463/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.2305 - mse: 146.1388 - val_loss: 3.3228 - val_mse: 175.5254
# Epoch 464/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.4580 - mse: 230.5654 - val_loss: 3.2878 - val_mse: 103.9537
# Epoch 465/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.4134 - mse: 166.5257 - val_loss: 3.3657 - val_mse: 148.4378
# Epoch 466/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.3522 - mse: 180.3084 - val_loss: 3.3177 - val_mse: 118.2105
# Epoch 467/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.3794 - mse: 205.0735 - val_loss: 3.0257 - val_mse: 136.2222
# Epoch 468/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.3648 - mse: 190.9533 - val_loss: 3.5795 - val_mse: 95.1281
# Epoch 469/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.2381 - mse: 120.3443 - val_loss: 2.9439 - val_mse: 103.3747
# Epoch 470/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.4059 - mse: 210.4835 - val_loss: 3.4428 - val_mse: 79.3536
# Epoch 471/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 3.3089 - mse: 172.2912 - val_loss: 2.8812 - val_mse: 72.4799
# Epoch 472/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 3.2773 - mse: 201.3210 - val_loss: 2.8933 - val_mse: 115.5410
# Epoch 473/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.1251 - mse: 149.7196 - val_loss: 2.7179 - val_mse: 85.2657
# Epoch 474/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.3546 - mse: 183.2718 - val_loss: 2.8074 - val_mse: 143.3040
# Epoch 475/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.4091 - mse: 192.8366 - val_loss: 3.0642 - val_mse: 213.6294
# Epoch 476/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.4796 - mse: 190.7574 - val_loss: 3.8851 - val_mse: 172.4495
# Epoch 477/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.3298 - mse: 193.6811 - val_loss: 2.7827 - val_mse: 109.1735
# Epoch 478/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.4506 - mse: 204.8234 - val_loss: 3.2099 - val_mse: 99.3168
# Epoch 479/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.2453 - mse: 166.1012 - val_loss: 2.8077 - val_mse: 128.1844
# Epoch 480/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.1118 - mse: 141.0677 - val_loss: 3.0971 - val_mse: 107.1151
# Epoch 481/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.2938 - mse: 201.6156 - val_loss: 3.5887 - val_mse: 226.0554
# Epoch 482/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.2528 - mse: 224.1941 - val_loss: 3.2003 - val_mse: 174.7639
# Epoch 483/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.2562 - mse: 157.5833 - val_loss: 2.7608 - val_mse: 117.2536
# Epoch 484/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.2367 - mse: 164.3478 - val_loss: 2.6533 - val_mse: 58.4613
# Epoch 485/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.4025 - mse: 247.7418 - val_loss: 2.8294 - val_mse: 111.2265
# Epoch 486/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.1762 - mse: 151.3907 - val_loss: 3.0018 - val_mse: 144.0371
# Epoch 487/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 3.2474 - mse: 150.1530 - val_loss: 3.1872 - val_mse: 156.4014
# Epoch 488/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.6773 - mse: 253.2585 - val_loss: 3.1012 - val_mse: 96.4389
# Epoch 489/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.2178 - mse: 119.3584 - val_loss: 2.6154 - val_mse: 66.8321
# Epoch 490/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 3.1092 - mse: 165.6882 - val_loss: 2.7261 - val_mse: 126.6069
# Epoch 491/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.2463 - mse: 173.2238 - val_loss: 2.5222 - val_mse: 56.7822
# Epoch 492/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.3266 - mse: 165.7445 - val_loss: 3.3164 - val_mse: 78.4574
# Epoch 493/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 3.3955 - mse: 238.6919 - val_loss: 2.8555 - val_mse: 73.1191
# Epoch 494/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.5964 - mse: 191.1687 - val_loss: 2.9555 - val_mse: 169.0310
# Epoch 495/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.3737 - mse: 157.2553 - val_loss: 2.8012 - val_mse: 174.6057
# Epoch 496/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.3134 - mse: 198.8361 - val_loss: 3.4319 - val_mse: 106.2080
# Epoch 497/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 3.3218 - mse: 148.4187 - val_loss: 2.6094 - val_mse: 94.1469
# Epoch 498/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.3190 - mse: 259.7211 - val_loss: 2.8962 - val_mse: 246.9653
# Epoch 499/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.2303 - mse: 184.3406 - val_loss: 2.9544 - val_mse: 236.8510
# Epoch 500/500
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3.4715 - mse: 199.2519 - val_loss: 3.0239 - val_mse: 75.0596
# 2025/11/20 14:33:49 WARNING mlflow.keras.autologging: Failed to get model signature, reason: Creating Schema with multiple unnamed TensorSpecs is not supported. Please provide names for each TensorSpec.
# 2025/11/20 14:33:49 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/11/20 14:33:52 WARNING mlflow.keras.save: You are saving a Keras model without specifying model signature.
# 2025/11/20 14:34:19 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run Mlflow_modelo_Airbnb_pred at: http://localhost:5000/#/experiments/933597535789669518/runs/6da078bf08944b2bb7e418c66e14302f
# 🧪 View experiment at: http://localhost:5000/#/experiments/933597535789669518
# MLflow Run completed with run_id <keras.src.callbacks.history.History object at 0x00000250720CDE90> and experiment_id <Functional name=functional, built=True>

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
plt.scatter(df["review_scores_rating"], df["price"], label="Precio real")
#plt.scatter(df["review_scores_rating"], df["price_pred"], label="Precio predicho")
plt.legend()
plt.xlabel("Review Score Rating")
plt.ylabel("Precio")
plt.title("Comparación entre precio real y predicho por rating")
# Out:
# Text(0.5, 1.0, 'Comparación entre precio real y predicho por rating')

# %%
experimentID.

# %%
type(test_ds)
# Out:
# tensorflow.python.data.ops.shuffle_op._ShuffleDataset

# %%
# ...existing code...
# Celda nueva: obtener predicciones y graficar review_scores_rating vs precio real y predicho

import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error

batch_size = 32

model = experimentID
# Dataset solo con features (en el mismo orden esperado por el modelo) y en batches para predecir
test_features_ds = test_ds.map(lambda x, y: x).batch(batch_size)

# Predicciones (aplana salida)
preds = model.predict(test_features_ds).flatten()

# Extraer precios reales y review_scores_rating desde el test_ds (sin batch)
test_y = np.array([y.numpy() for x, y in test_ds])
test_review = np.array([x['review_scores_rating'].numpy() for x, y in test_ds])

# Si hay NaNs en review_scores_rating, filtrarlos para la gráfica
mask = ~np.isnan(test_review)
test_review = test_review[mask]
test_y = test_y[mask]
preds = preds[mask]

# Gráfica comparativa
plt.figure(figsize=(10,6))
plt.scatter(test_review, test_y, alpha=0.6, label='Precio real')
plt.scatter(test_review, preds, alpha=0.6, label='Precio predicho', marker='x')
plt.xlabel('review_scores_rating')
plt.ylabel('Precio')
plt.title('Review score rating vs Precio real y predicho')
plt.legend()
plt.grid(True)
plt.show()

# Métricas de desempeño
print('MSE:', mean_squared_error(test_y, preds))
print('MAE:', mean_absolute_error(test_y, preds))
# ...existing code...
# Out:
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MSE: 255956.73972817033
# MAE: 171.08499623404228

# %%
batch_size = 32
model = experimentID
# Dataset solo con features para predecir
test_features_ds = test_ds.map(lambda x, y: x).batch(batch_size)

# Predicciones (aplana salida)
preds = model.predict(test_features_ds).flatten()

# Extraer precios reales y flag host_is_superhost desde test_ds (sin batch)
test_y = np.array([y.numpy() for x, y in test_ds])
host_flag = np.array([x['host_is_superhost'].numpy() for x, y in test_ds])

# Alinear longitudes por si hubo diferencias (usa la longitud mínima)
n = min(len(preds), len(test_y), len(host_flag))
preds = preds[:n]
test_y = test_y[:n]
host_flag = host_flag[:n]

# Scatter con jitter para visualizar ambos grupos 0/1
rng = np.random.default_rng(42)
jitter = (rng.random(n) - 0.5) * 0.1

plt.figure(figsize=(10,6))
plt.scatter(host_flag + jitter, test_y, alpha=0.6, label='Precio real')
plt.scatter(host_flag + jitter, preds, alpha=0.6, label='Precio predicho', marker='x')
plt.xticks([0,1], ['No superhost', 'Superhost'])
plt.xlabel('host_is_superhost')
plt.ylabel('Precio')
# Out:
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Text(0, 0.5, 'Precio')

# %%
# ...existing code...
# Celda nueva: True values vs Predicted (global y por host_is_superhost)

import numpy as np
import matplotlib.pyplot as plt

# Seleccionar modelo disponible (intenta varias variables comunes)
model = globals().get("model",
         globals().get("first_model",
         globals().get("experimentID", None)))
if model is None:
    raise RuntimeError("No se encontró un modelo en 'model', 'first_model' ni 'experimentID'.")

# Obtener predicciones usando test_ds (features en batches)
batch_size = 32
test_features_ds = test_ds.map(lambda x, y: x).batch(batch_size)
preds = model.predict(test_features_ds).flatten()

# Extraer verdaderos y flag de superhost desde test_ds (sin batching)
test_y = np.array([y.numpy() for x, y in test_ds])
host_flag = np.array([x['host_is_superhost'].numpy() for x, y in test_ds])

# Alinear longitudes
n = min(len(preds), len(test_y), len(host_flag))
preds = preds[:n]
test_y = test_y[:n]
host_flag = host_flag[:n]

print("shapes -> preds:", preds.shape, "true:", test_y.shape)

# Función auxiliar para graficar True vs Pred
def plot_true_vs_pred(ax, y_true, y_pred, title):
    ax.scatter(y_true, y_pred, alpha=0.6)
    ax.set_aspect('equal', adjustable='box')
    ax.set_xlabel('True Values [Precio]')
    ax.set_ylabel('Predictions [Precio]')
    lim_max = max(50, np.nanmax(y_true), np.nanmax(y_pred))
    lims = [0, lim_max]
    ax.set_xlim(lims)
    ax.set_ylim(lims)
    ax.plot(lims, lims, color='red', linewidth=1)
    ax.set_title(title)

# Crear figura: global + dos subplots por categoría
fig, axes = plt.subplots(1, 3, figsize=(18,6))
plot_true_vs_pred(axes[0], test_y, preds, f"Global (n={n})")

for i, val in enumerate([0, 1], start=1):
    mask = host_flag == val
    if mask.sum() == 0:
        axes[i].text(0.5, 0.5, f"No hay muestras para {val}", ha='center')
        axes[i].set_title(f"host_is_superhost={val} (n=0)")
        axes[i].set_xlabel('True Values [Precio]')
        axes[i].set_ylabel('Predictions [Precio]')
        continue
    plot_true_vs_pred(axes[i], test_y[mask], preds[mask], f"host_is_superhost={val} (n={mask.sum()})")

plt.suptitle("True vs Predicted — Global y por host_is_superhost")
plt.tight_layout()
plt.show()
# ...existing code...
# Out:
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# shapes -> preds: (2791,) true: (2791,)
